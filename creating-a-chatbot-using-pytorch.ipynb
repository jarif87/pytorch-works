# %%
import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# Load & Preprocess Data
# ======================
#
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)
# is a rich dataset of movie character dialog:
#
# -   220,579 conversational exchanges between 10,292 pairs of movie
#     characters
# -   9,035 characters from 617 movies
# -   304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we'll take a look at some lines of our datafile to see the
# original format.

# %%
corpus_path = "/kaggle/input/cornell-movie-dialogs-corpus/movie-corpus/movie-corpus"

def printLines(file, n=10):
    with open(file, 'r', encoding='utf-8') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        try:
            data = json.loads(line.strip())
            print(json.dumps(data, indent=4))
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}\nLine: {line}")

jsonl_file = os.path.join(corpus_path, "utterances.jsonl")

printLines(jsonl_file)
# Out:
# {
#     "id": "L1045",
#     "conversation_id": "L1044",
#     "text": "They do not!",
#     "speaker": "u0",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 1,
#                 "toks": [
#                     {
#                         "tok": "They",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 1,
#                         "dn": []
#                     },
#                     {
#                         "tok": "do",
#                         "tag": "VBP",
#                         "dep": "ROOT",
#                         "dn": [
#                             0,
#                             2,
#                             3
#                         ]
#                     },
#                     {
#                         "tok": "not",
#                         "tag": "RB",
#                         "dep": "neg",
#                         "up": 1,
#                         "dn": []
#                     },
#                     {
#                         "tok": "!",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 1,
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": "L1044",
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L1044",
#     "conversation_id": "L1044",
#     "text": "They do to!",
#     "speaker": "u2",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 1,
#                 "toks": [
#                     {
#                         "tok": "They",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 1,
#                         "dn": []
#                     },
#                     {
#                         "tok": "do",
#                         "tag": "VBP",
#                         "dep": "ROOT",
#                         "dn": [
#                             0,
#                             2,
#                             3
#                         ]
#                     },
#                     {
#                         "tok": "to",
#                         "tag": "TO",
#                         "dep": "dobj",
#                         "up": 1,
#                         "dn": []
#                     },
#                     {
#                         "tok": "!",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 1,
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": null,
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L985",
#     "conversation_id": "L984",
#     "text": "I hope so.",
#     "speaker": "u0",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 1,
#                 "toks": [
#                     {
#                         "tok": "I",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 1,
#                         "dn": []
#                     },
#                     {
#                         "tok": "hope",
#                         "tag": "VBP",
#                         "dep": "ROOT",
#                         "dn": [
#                             0,
#                             2,
#                             3
#                         ]
#                     },
#                     {
#                         "tok": "so",
#                         "tag": "RB",
#                         "dep": "advmod",
#                         "up": 1,
#                         "dn": []
#                     },
#                     {
#                         "tok": ".",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 1,
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": "L984",
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L984",
#     "conversation_id": "L984",
#     "text": "She okay?",
#     "speaker": "u2",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 1,
#                 "toks": [
#                     {
#                         "tok": "She",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 1,
#                         "dn": []
#                     },
#                     {
#                         "tok": "okay",
#                         "tag": "RB",
#                         "dep": "ROOT",
#                         "dn": [
#                             0,
#                             2
#                         ]
#                     },
#                     {
#                         "tok": "?",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 1,
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": null,
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L925",
#     "conversation_id": "L924",
#     "text": "Let's go.",
#     "speaker": "u0",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 0,
#                 "toks": [
#                     {
#                         "tok": "Let",
#                         "tag": "VB",
#                         "dep": "ROOT",
#                         "dn": [
#                             2,
#                             3
#                         ]
#                     },
#                     {
#                         "tok": "'s",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 2,
#                         "dn": []
#                     },
#                     {
#                         "tok": "go",
#                         "tag": "VB",
#                         "dep": "ccomp",
#                         "up": 0,
#                         "dn": [
#                             1
#                         ]
#                     },
#                     {
#                         "tok": ".",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 0,
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": "L924",
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L924",
#     "conversation_id": "L924",
#     "text": "Wow",
#     "speaker": "u2",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 0,
#                 "toks": [
#                     {
#                         "tok": "Wow",
#                         "tag": "UH",
#                         "dep": "ROOT",
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": null,
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L872",
#     "conversation_id": "L870",
#     "text": "Okay -- you're gonna need to learn how to lie.",
#     "speaker": "u0",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 4,
#                 "toks": [
#                     {
#                         "tok": "Okay",
#                         "tag": "UH",
#                         "dep": "intj",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "--",
#                         "tag": ":",
#                         "dep": "punct",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "you",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "'re",
#                         "tag": "VBP",
#                         "dep": "aux",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "gon",
#                         "tag": "VBG",
#                         "dep": "ROOT",
#                         "dn": [
#                             0,
#                             1,
#                             2,
#                             3,
#                             6,
#                             12
#                         ]
#                     },
#                     {
#                         "tok": "na",
#                         "tag": "TO",
#                         "dep": "aux",
#                         "up": 6,
#                         "dn": []
#                     },
#                     {
#                         "tok": "need",
#                         "tag": "VB",
#                         "dep": "xcomp",
#                         "up": 4,
#                         "dn": [
#                             5,
#                             8
#                         ]
#                     },
#                     {
#                         "tok": "to",
#                         "tag": "TO",
#                         "dep": "aux",
#                         "up": 8,
#                         "dn": []
#                     },
#                     {
#                         "tok": "learn",
#                         "tag": "VB",
#                         "dep": "xcomp",
#                         "up": 6,
#                         "dn": [
#                             7,
#                             11
#                         ]
#                     },
#                     {
#                         "tok": "how",
#                         "tag": "WRB",
#                         "dep": "advmod",
#                         "up": 11,
#                         "dn": []
#                     },
#                     {
#                         "tok": "to",
#                         "tag": "TO",
#                         "dep": "aux",
#                         "up": 11,
#                         "dn": []
#                     },
#                     {
#                         "tok": "lie",
#                         "tag": "VB",
#                         "dep": "xcomp",
#                         "up": 8,
#                         "dn": [
#                             9,
#                             10
#                         ]
#                     },
#                     {
#                         "tok": ".",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 4,
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": "L871",
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L871",
#     "conversation_id": "L870",
#     "text": "No",
#     "speaker": "u2",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 0,
#                 "toks": [
#                     {
#                         "tok": "No",
#                         "tag": "UH",
#                         "dep": "ROOT",
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": "L870",
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L870",
#     "conversation_id": "L870",
#     "text": "I'm kidding.  You know how sometimes you just become this \"persona\"?  And you don't know how to quit?",
#     "speaker": "u0",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 2,
#                 "toks": [
#                     {
#                         "tok": "I",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 2,
#                         "dn": []
#                     },
#                     {
#                         "tok": "'m",
#                         "tag": "VBP",
#                         "dep": "aux",
#                         "up": 2,
#                         "dn": []
#                     },
#                     {
#                         "tok": "kidding",
#                         "tag": "VBG",
#                         "dep": "ROOT",
#                         "dn": [
#                             0,
#                             1,
#                             3
#                         ]
#                     },
#                     {
#                         "tok": ".",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 2,
#                         "dn": [
#                             4
#                         ]
#                     },
#                     {
#                         "tok": " ",
#                         "tag": "_SP",
#                         "dep": "",
#                         "up": 3,
#                         "dn": []
#                     }
#                 ]
#             },
#             {
#                 "rt": 1,
#                 "toks": [
#                     {
#                         "tok": "You",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 1,
#                         "dn": []
#                     },
#                     {
#                         "tok": "know",
#                         "tag": "VBP",
#                         "dep": "ROOT",
#                         "dn": [
#                             0,
#                             6,
#                             11
#                         ]
#                     },
#                     {
#                         "tok": "how",
#                         "tag": "WRB",
#                         "dep": "advmod",
#                         "up": 3,
#                         "dn": []
#                     },
#                     {
#                         "tok": "sometimes",
#                         "tag": "RB",
#                         "dep": "advmod",
#                         "up": 6,
#                         "dn": [
#                             2
#                         ]
#                     },
#                     {
#                         "tok": "you",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 6,
#                         "dn": []
#                     },
#                     {
#                         "tok": "just",
#                         "tag": "RB",
#                         "dep": "advmod",
#                         "up": 6,
#                         "dn": []
#                     },
#                     {
#                         "tok": "become",
#                         "tag": "VBP",
#                         "dep": "ccomp",
#                         "up": 1,
#                         "dn": [
#                             3,
#                             4,
#                             5,
#                             9
#                         ]
#                     },
#                     {
#                         "tok": "this",
#                         "tag": "DT",
#                         "dep": "det",
#                         "up": 9,
#                         "dn": []
#                     },
#                     {
#                         "tok": "\"",
#                         "tag": "``",
#                         "dep": "punct",
#                         "up": 9,
#                         "dn": []
#                     },
#                     {
#                         "tok": "persona",
#                         "tag": "NN",
#                         "dep": "attr",
#                         "up": 6,
#                         "dn": [
#                             7,
#                             8,
#                             10
#                         ]
#                     },
#                     {
#                         "tok": "\"",
#                         "tag": "''",
#                         "dep": "punct",
#                         "up": 9,
#                         "dn": []
#                     },
#                     {
#                         "tok": "?",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 1,
#                         "dn": [
#                             12
#                         ]
#                     },
#                     {
#                         "tok": " ",
#                         "tag": "_SP",
#                         "dep": "",
#                         "up": 11,
#                         "dn": []
#                     }
#                 ]
#             },
#             {
#                 "rt": 4,
#                 "toks": [
#                     {
#                         "tok": "And",
#                         "tag": "CC",
#                         "dep": "cc",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "you",
#                         "tag": "PRP",
#                         "dep": "nsubj",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "do",
#                         "tag": "VBP",
#                         "dep": "aux",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "n't",
#                         "tag": "RB",
#                         "dep": "neg",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "know",
#                         "tag": "VB",
#                         "dep": "ROOT",
#                         "dn": [
#                             0,
#                             1,
#                             2,
#                             3,
#                             7,
#                             8
#                         ]
#                     },
#                     {
#                         "tok": "how",
#                         "tag": "WRB",
#                         "dep": "advmod",
#                         "up": 7,
#                         "dn": []
#                     },
#                     {
#                         "tok": "to",
#                         "tag": "TO",
#                         "dep": "aux",
#                         "up": 7,
#                         "dn": []
#                     },
#                     {
#                         "tok": "quit",
#                         "tag": "VB",
#                         "dep": "xcomp",
#                         "up": 4,
#                         "dn": [
#                             5,
#                             6
#                         ]
#                     },
#                     {
#                         "tok": "?",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 4,
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": null,
#     "timestamp": null,
#     "vectors": []
# }
# {
#     "id": "L869",
#     "conversation_id": "L866",
#     "text": "Like my fear of wearing pastels?",
#     "speaker": "u0",
#     "meta": {
#         "movie_id": "m0",
#         "parsed": [
#             {
#                 "rt": 0,
#                 "toks": [
#                     {
#                         "tok": "Like",
#                         "tag": "IN",
#                         "dep": "ROOT",
#                         "dn": [
#                             2,
#                             6
#                         ]
#                     },
#                     {
#                         "tok": "my",
#                         "tag": "PRP$",
#                         "dep": "poss",
#                         "up": 2,
#                         "dn": []
#                     },
#                     {
#                         "tok": "fear",
#                         "tag": "NN",
#                         "dep": "pobj",
#                         "up": 0,
#                         "dn": [
#                             1,
#                             3
#                         ]
#                     },
#                     {
#                         "tok": "of",
#                         "tag": "IN",
#                         "dep": "prep",
#                         "up": 2,
#                         "dn": [
#                             4
#                         ]
#                     },
#                     {
#                         "tok": "wearing",
#                         "tag": "VBG",
#                         "dep": "pcomp",
#                         "up": 3,
#                         "dn": [
#                             5
#                         ]
#                     },
#                     {
#                         "tok": "pastels",
#                         "tag": "NNS",
#                         "dep": "dobj",
#                         "up": 4,
#                         "dn": []
#                     },
#                     {
#                         "tok": "?",
#                         "tag": ".",
#                         "dep": "punct",
#                         "up": 0,
#                         "dn": []
#                     }
#                 ]
#             }
#         ]
#     },
#     "reply-to": "L868",
#     "timestamp": null,
#     "vectors": []
# }

# %% [markdown]
# Create formatted data file
# ==========================
#
# For convenience, we\'ll create a nicely formatted data file in which
# each line contains a tab-separated *query sentence* and a *response
# sentence* pair.
#
# The following functions facilitate the parsing of the raw
# `utterances.jsonl` data file.
#
# -   `loadLinesAndConversations` splits each line of the file into a
#     dictionary of lines with fields: `lineID`, `characterID`, and text
#     and then groups them into conversations with fields:
#     `conversationID`, `movieID`, and lines.
# -   `extractSentencePairs` extracts pairs of sentences from
#     conversations

# %%
# Splits each line of the file to create lines and conversations
def loadLinesAndConversations(fileName):
    lines = {}
    conversations = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            # Extract fields for line object
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj

            # Extract fields for conversation object
            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj

    return lines, conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations.values():
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we'll call these functions and create the file. We'll call it
# `formatted_movie_lines.txt`.

# %%
import os
import json
import csv
import codecs

datafile = "/kaggle/working/formatted_movie_lines.txt"

delimiter = '\t'
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

lines = {}
conversations = {}

print("\nProcessing corpus into lines and conversations...")
lines, conversations = loadLinesAndConversations("/kaggle/input/cornell-movie-dialogs-corpus/movie-corpus/movie-corpus/utterances.jsonl")

print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Line: They do to!	They do not!
#
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Line: She okay?	I hope so.
#
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Line: Wow	Let's go.
#
# Error decoding JSON: Extra data: line 1 column 61 (char 60)
# Line: "I'm kidding.  You know how sometimes you just become this ""persona""?  And you don't know how to quit?"	No
#
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Line: No	Okay -- you're gonna need to learn how to lie.
#
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Line: I figured you'd get to the good stuff eventually.	What good stuff?
#
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Line: What good stuff?	"The ""real you""."
#
# Error decoding JSON: Extra data: line 1 column 7 (char 6)
# Line: "The ""real you""."	Like my fear of wearing pastels?
#
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Line: do you listen to this crap?	What crap?
#
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Line: What crap?	Me.  This endless ...blonde babble. I'm like, boring myself.

# %% [markdown]
# Load and trim data
# ==================
#
# Our next order of business is to create a vocabulary and load
# query/response sentence pairs into memory.
#
# Note that we are dealing with sequences of **words**, which do not have
# an implicit mapping to a discrete numerical space. Thus, we must create
# one by mapping each unique word that we encounter in our dataset to an
# index value.
#
# For this we define a `Voc` class, which keeps a mapping from words to
# indexes, a reverse mapping of indexes to words, a count of each word and
# a total word count. The class provides methods for adding a word to the
# vocabulary (`addWord`), adding all words in a sentence (`addSentence`)
# and trimming infrequently seen words (`trim`). More on trimming later.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we can assemble our vocabulary and query/response sentence pairs.
# Before we are ready to use this data, we must perform some
# preprocessing.
#
# First, we must convert the Unicode strings to ASCII using
# `unicodeToAscii`. Next, we should convert all letters to lowercase and
# trim all non-letter characters except for basic punctuation
# (`normalizeString`). Finally, to aid in training convergence, we will
# filter out sentences with length greater than the `MAX_LENGTH` threshold
# (`filterPairs`).

# %%
import os
import unicodedata
import re

MAX_LENGTH = 10

def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

def readVocs(datafile, corpus_name):
    print("Reading lines...")
    lines = open(datafile, encoding='utf-8').read().strip().split('\n')
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print(f"Read {len(pairs)} sentence pairs")
    pairs = filterPairs(pairs)
    print(f"Trimmed to {len(pairs)} sentence pairs")
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print(f"Counted words: {voc.num_words}")
    return voc, pairs

corpus_name = "movie-corpus"
corpus = "/kaggle/input/cornell-movie-dialogs-corpus/movie-corpus/movie-corpus"  # Define the corpus path
datafile = "/kaggle/input/cornell-movie-dialogs-corpus/formatted_movie_lines.txt"
save_dir = os.path.join("data", "save")

voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)

print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64271 sentence pairs
# Counting words...
# Counted words: 18008
#
# pairs:
# ['there .', 'where ?']
# ['you have my word . as a gentleman', 'you re sweet .']
# ['hi .', 'looks like things worked out tonight huh ?']
# ['you know chastity ?', 'i believe we share an art instructor']
# ['have fun tonight ?', 'tons']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['what good stuff ?', 'the real you .']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1)  Trim words used under `MIN_COUNT` threshold using the `voc.trim`
#     function.
# 2)  Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7823 / 18005 = 0.4345
# Trimmed from 64271 pairs to 53165, 0.8272 of total

# %% [markdown]
# Prepare Data for Models
# =======================
#
# Although we have put a great deal of effort into preparing and massaging
# our data into a nice vocabulary object and list of sentence pairs, our
# models will ultimately expect numerical torch tensors as inputs. One way
# to prepare the processed data for the models can be found in the
# [seq2seq translation
# tutorial](https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html).
# In that tutorial, we use a batch size of 1, meaning that all we have to
# do is convert the words in our sentence pairs to their corresponding
# indexes from the vocabulary and feed this to the models.
#
# However, if you're interested in speeding up training and/or would like
# to leverage GPU parallelization capabilities, you will need to train
# with mini-batches.
#
# Using mini-batches also means that we must be mindful of the variation
# of sentence length in our batches. To accommodate sentences of different
# sizes in the same batch, we will make our batched input tensor of shape
# *(max\_length, batch\_size)*, where sentences shorter than the
# *max\_length* are zero padded after an *EOS\_token*.
#
# If we simply convert our English sentences to tensors by converting
# words to their indexes(`indexesFromSentence`) and zero-pad, our tensor
# would have shape *(batch\_size, max\_length)* and indexing the first
# dimension would return a full sequence across all time-steps. However,
# we need to be able to index our batch along time, and across all
# sequences in the batch. Therefore, we transpose our input batch shape to
# *(max\_length, batch\_size)*, so that indexing across the first
# dimension returns a time step across all sentences in the batch. We
# handle this transpose implicitly in the `zeroPadding` function.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/seq2seq_batches.png){.align-center}
#
# The `inputVar` function handles the process of converting sentences to
# tensor, ultimately creating a correctly shaped zero-padded tensor. It
# also returns a tensor of `lengths` for each of the sequences in the
# batch which will be passed to our decoder later.
#
# The `outputVar` function performs a similar function to `inputVar`, but
# instead of returning a `lengths` tensor, it returns a binary mask tensor
# and a maximum target sentence length. The binary mask tensor has the
# same shape as the output target tensor, but every element that is a
# *PAD\_token* is 0 and all others are 1.
#
# `batch2TrainData` simply takes a bunch of pairs and returns the input
# and target tensors using the aforementioned functions.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  50,   25,   25,   50,   34],
#         [  96,  102,  534, 1490,    4],
#         [  53, 2051,    7,    6,    2],
#         [ 654,    4,    4,    2,    0],
#         [ 115,    4,    2,    0,    0],
#         [  76,    4,    0,    0,    0],
#         [   6,    2,    0,    0,    0],
#         [  66,    0,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 7, 5, 4, 3])
# target_variable: tensor([[  76,  318,    5, 6685, 2544],
#         [  37,    6,   37,    4,    4],
#         [  53,    2,   53,   98,    2],
#         [ 849,    0,  596,    9,    0],
#         [2954,    0,    6,  701,    0],
#         [3526,    0,    2,    4,    0],
#         [  66,    0,    0,    2,    0],
#         [   2,    0,    0,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False,  True,  True, False],
#         [ True, False,  True,  True, False],
#         [ True, False,  True,  True, False],
#         [ True, False, False,  True, False],
#         [ True, False, False, False, False]])
# max_target_len: 8

# %% [markdown]
# Define Models
# =============
#
# Seq2Seq Model
# -------------
#
# The brains of our chatbot is a sequence-to-sequence (seq2seq) model. The
# goal of a seq2seq model is to take a variable-length sequence as an
# input, and return a variable-length sequence as an output using a
# fixed-sized model.
#
# [Sutskever et al.](https://arxiv.org/abs/1409.3215) discovered that by
# using two separate recurrent neural nets together, we can accomplish
# this task. One RNN acts as an **encoder**, which encodes a variable
# length input sequence to a fixed-length context vector. In theory, this
# context vector (the final hidden layer of the RNN) will contain semantic
# information about the query sentence that is input to the bot. The
# second RNN is a **decoder**, which takes an input word and the context
# vector, and returns a guess for the next word in the sequence and a
# hidden state to use in the next iteration.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/seq2seq_ts.png){.align-center}
#
# Image source:
# <https://jeddy92.github.io/JEddy92.github.io/ts_seq2seq_intro/>

# %% [markdown]
# Encoder
# =======
#
# The encoder RNN iterates through the input sentence one token
# (e.g. word) at a time, at each time step outputting an "output" vector
# and a "hidden state" vector. The hidden state vector is then passed to
# the next time step, while the output vector is recorded. The encoder
# transforms the context it saw at each point in the sequence into a set
# of points in a high-dimensional space, which the decoder will use to
# generate a meaningful output for the given task.
#
# At the heart of our encoder is a multi-layered Gated Recurrent Unit,
# invented by [Cho et al.](https://arxiv.org/pdf/1406.1078v3.pdf) in 2014.
# We will use a bidirectional variant of the GRU, meaning that there are
# essentially two independent RNNs: one that is fed the input sequence in
# normal sequential order, and one that is fed the input sequence in
# reverse order. The outputs of each network are summed at each time step.
# Using a bidirectional GRU will give us the advantage of encoding both
# past and future contexts.
#
# Bidirectional RNN:
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/RNN-bidirectional.png){.align-center
# width="70.0%"}
#
# Image source: <https://colah.github.io/posts/2015-09-NN-Types-FP/>
#
# Note that an `embedding` layer is used to encode our word indices in an
# arbitrarily sized feature space. For our models, this layer will map
# each word to a feature space of size *hidden\_size*. When trained, these
# values should encode semantic similarity between similar meaning words.
#
# Finally, if passing a padded batch of sequences to an RNN module, we
# must pack and unpack padding around the RNN pass using
# `nn.utils.rnn.pack_padded_sequence` and
# `nn.utils.rnn.pad_packed_sequence` respectively.
#
# **Computation Graph:**
#
# > 1)  Convert word indexes to embeddings.
# > 2)  Pack padded batch of sequences for RNN module.
# > 3)  Forward pass through GRU.
# > 4)  Unpack padding.
# > 5)  Sum bidirectional GRU outputs.
# > 6)  Return output and final hidden state.
#
# **Inputs:**
#
# -   `input_seq`: batch of input sentences; shape=*(max\_length,
#     batch\_size)*
# -   `input_lengths`: list of sentence lengths corresponding to each
#     sentence in the batch; shape=*(batch\_size)*
# -   `hidden`: hidden state; shape=*(n\_layers x num\_directions,
#     batch\_size, hidden\_size)*
#
# **Outputs:**
#
# -   `outputs`: output features from the last hidden layer of the GRU
#     (sum of bidirectional outputs); shape=*(max\_length, batch\_size,
#     hidden\_size)*
# -   `hidden`: updated hidden state from GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size parameters are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Decoder
# =======
#
# The decoder RNN generates the response sentence in a token-by-token
# fashion. It uses the encoder's context vectors, and internal hidden
# states to generate the next word in the sequence. It continues
# generating words until it outputs an *EOS\_token*, representing the end
# of the sentence. A common problem with a vanilla seq2seq decoder is that
# if we rely solely on the context vector to encode the entire input
# sequence's meaning, it is likely that we will have information loss.
# This is especially the case when dealing with long input sequences,
# greatly limiting the capability of our decoder.
#
# To combat this, [Bahdanau et al.](https://arxiv.org/abs/1409.0473)
# created an "attention mechanism" that allows the decoder to pay
# attention to certain parts of the input sequence, rather than using the
# entire fixed context at every step.
#
# At a high level, attention is calculated using the decoder's current
# hidden state and the encoder's outputs. The output attention weights
# have the same shape as the input sequence, allowing us to multiply them
# by the encoder outputs, giving us a weighted sum which indicates the
# parts of encoder output to pay attention to. [Sean
# Robertson's](https://github.com/spro) figure describes this very well:
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/attn2.png){.align-center}
#
# [Luong et al.](https://arxiv.org/abs/1508.04025) improved upon Bahdanau
# et al.'s groundwork by creating "Global attention". The key difference
# is that with "Global attention", we consider all of the encoder's hidden
# states, as opposed to Bahdanau et al.'s "Local attention", which only
# considers the encoder's hidden state from the current time step. Another
# difference is that with "Global attention", we calculate attention
# weights, or energies, using the hidden state of the decoder from the
# current time step only. Bahdanau et al.'s attention calculation requires
# knowledge of the decoder's state from the previous time step. Also,
# Luong et al. provides various methods to calculate the attention
# energies between the encoder output and decoder output which are called
# "score functions":
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/scores.png){.align-center
# width="60.0%"}
#
# where $h_t$ = current target decoder state and $\bar{h}_s$ = all encoder
# states.
#
# Overall, the Global attention mechanism can be summarized by the
# following figure. Note that we will implement the "Attention Layer" as a
# separate `nn.Module` called `Attn`. The output of this module is a
# softmax normalized weights tensor of shape *(batch\_size, 1,
# max\_length)*.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/global_attn.png){.align-center
# width="60.0%"}

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %% [markdown]
# Now that we have defined our attention submodule, we can implement the
# actual decoder model. For the decoder, we will manually feed our batch
# one time step at a time. This means that our embedded word tensor and
# GRU output will both have shape *(1, batch\_size, hidden\_size)*.
#
# **Computation Graph:**
#
# > 1)  Get embedding of current input word.
# > 2)  Forward through unidirectional GRU.
# > 3)  Calculate attention weights from the current GRU output from (2).
# > 4)  Multiply attention weights to encoder outputs to get new
# >     \"weighted sum\" context vector.
# > 5)  Concatenate weighted context vector and GRU output using Luong
# >     eq. 5.
# > 6)  Predict next word using Luong eq. 6 (without softmax).
# > 7)  Return output and final hidden state.
#
# **Inputs:**
#
# -   `input_step`: one time step (one word) of input sequence batch;
#     shape=*(1, batch\_size)*
# -   `last_hidden`: final hidden layer of GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*
# -   `encoder_outputs`: encoder model's output; shape=*(max\_length,
#     batch\_size, hidden\_size)*
#
# **Outputs:**
#
# -   `output`: softmax normalized tensor giving probabilities of each
#     word being the correct next word in the decoded sequence;
#     shape=*(batch\_size, voc.num\_words)*
# -   `hidden`: final hidden state of GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# Define Training Procedure
# =========================
#
# Masked loss
# -----------
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# `maskNLLLoss` to calculate our loss based on our decoder's output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# Single training iteration
# =========================
#
# The `train` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -   The first trick is using **teacher forcing**. This means that at
#     some probability, set by `teacher_forcing_ratio`, we use the current
#     target word as the decoder's next input rather than using the
#     decoder's current guess. This technique acts as training wheels for
#     the decoder, aiding in more efficient training. However, teacher
#     forcing can lead to model instability during inference, as the
#     decoder may not have a sufficient chance to truly craft its own
#     output sequences during training. Thus, we must be mindful of how we
#     are setting the `teacher_forcing_ratio`, and not be fooled by fast
#     convergence.
# -   The second trick that we implement is **gradient clipping**. This is
#     a commonly used technique for countering the "exploding gradient"
#     problem. In essence, by clipping or thresholding gradients to a
#     maximum value, we prevent the gradients from growing exponentially
#     and either overflow (NaN), or overshoot steep cliffs in the cost
#     function.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/grad_clip.png){.align-center
# width="60.0%"}
#
# Image source: Goodfellow et al. *Deep Learning*. 2016.
# <https://www.deeplearningbook.org/>
#
# **Sequence of Operations:**
#
# > 1)  Forward pass entire input batch through encoder.
# > 2)  Initialize decoder inputs as SOS\_token, and hidden state as the
# >     encoder\'s final hidden state.
# > 3)  Forward input batch sequence through decoder one time step at a
# >     time.
# > 4)  If teacher forcing: set next decoder input as the current target;
# >     else: set next decoder input as current decoder output.
# > 5)  Calculate and accumulate loss.
# > 6)  Perform backpropagation.
# > 7)  Clip gradients.
# > 8)  Update encoder and decoder model parameters.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# Training iterations
# ===================
#
# It is finally time to tie the full training procedure together with the
# data. The `trainIters` function is responsible for running
# `n_iterations` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the `train` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder `state_dicts` (parameters), the
# optimizers' `state_dicts`, the loss, the iteration, etc. Saving the
# model in this way will give us the ultimate flexibility with the
# checkpoint. After loading a checkpoint, we will be able to use the model
# parameters to run inference, or we can continue training right where we
# left off.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# Define Evaluation
# =================
#
# After training a model, we want to be able to talk to the bot ourselves.
# First, we must define how we want the model to decode the encoded input.
#
# Greedy decoding
# ---------------
#
# Greedy decoding is the decoding method that we use during training when
# we are **NOT** using teacher forcing. In other words, for each time
# step, we simply choose the word from `decoder_output` with the highest
# softmax value. This decoding method is optimal on a single time-step
# level.
#
# To facilitate the greedy decoding operation, we define a
# `GreedySearchDecoder` class. When run, an object of this class takes an
# input sequence (`input_seq`) of shape *(input\_seq length, 1)*, a scalar
# input length (`input_length`) tensor, and a `max_length` to bound the
# response sentence length. The input sentence is evaluated using the
# following computational graph:
#
# **Computation Graph:**
#
# > 1)  Forward input through encoder model.
# >
# > 2)  Prepare encoder\'s final hidden layer to be first hidden input to
# >     the decoder.
# >
# > 3)  Initialize decoder\'s first input as SOS\_token.
# >
# > 4)  Initialize tensors to append decoded words to.
# >
# > 5)
# >
# >     Iteratively decode one word token at a time:
# >
# >     :   a)  Forward pass through decoder.
# >         b)  Obtain most likely word token and its softmax score.
# >         c)  Record token and score.
# >         d)  Prepare current token to be next decoder input.
# >
# > 6)  Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self.decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# Evaluate my text
# ================
#
# Now that we have our decoding method defined, we can write functions for
# evaluating a string input sentence. The `evaluate` function manages the
# low-level process of handling the input sentence. We first format the
# sentence as an input batch of word indexes with *batch\_size==1*. We do
# this by converting the words of the sentence to their corresponding
# indexes, and transposing the dimensions to prepare the tensor for our
# models. We also create a `lengths` tensor which contains the length of
# our input sentence. In this case, `lengths` is scalar because we are
# only evaluating one sentence at a time (batch\_size==1). Next, we obtain
# the decoded response sentence tensor using our `GreedySearchDecoder`
# object (`searcher`). Finally, we convert the response's indexes to words
# and return the list of decoded words.
#
# `evaluateInput` acts as the user interface for our chatbot. When called,
# an input text field will spawn in which we can enter our query sentence.
# After typing our input sentence and pressing *Enter*, our text is
# normalized in the same way as our training data, and is ultimately fed
# to the `evaluate` function to obtain a decoded output sentence. We loop
# this process, so we can keep chatting with our bot until we enter either
# "q" or "quit".
#
# Finally, if a sentence is entered that contains a word that is not in
# the vocabulary, we handle this gracefully by printing an error message
# and prompting the user to enter another sentence.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# Run Model
# =========
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000

# %% [markdown]
# Sample code to load from a checkpoint:
#
# ``` {.python}
# loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                     '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                     '{}_checkpoint.tar'.format(checkpoint_iter))
# ```

# %%
# Load model if a ``loadFilename`` is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Run Training
# ============
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the `trainIters` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 5000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have CUDA, configure CUDA to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9647
# Iteration: 2; Percent complete: 0.0%; Average loss: 8.8127
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6165
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.2115
# Iteration: 5; Percent complete: 0.1%; Average loss: 7.7743
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.1883
# Iteration: 7; Percent complete: 0.1%; Average loss: 6.8753
# Iteration: 8; Percent complete: 0.2%; Average loss: 6.7603
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.8824
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.6350
# Iteration: 11; Percent complete: 0.2%; Average loss: 6.3603
# Iteration: 12; Percent complete: 0.2%; Average loss: 5.8669
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.9077
# Iteration: 14; Percent complete: 0.3%; Average loss: 5.5931
# Iteration: 15; Percent complete: 0.3%; Average loss: 5.5757
# Iteration: 16; Percent complete: 0.3%; Average loss: 5.2221
# Iteration: 17; Percent complete: 0.3%; Average loss: 5.3268
# Iteration: 18; Percent complete: 0.4%; Average loss: 4.9108
# Iteration: 19; Percent complete: 0.4%; Average loss: 5.2283
# Iteration: 20; Percent complete: 0.4%; Average loss: 4.8869
# Iteration: 21; Percent complete: 0.4%; Average loss: 4.7721
# Iteration: 22; Percent complete: 0.4%; Average loss: 4.8945
# Iteration: 23; Percent complete: 0.5%; Average loss: 4.9140
# Iteration: 24; Percent complete: 0.5%; Average loss: 4.8696
# Iteration: 25; Percent complete: 0.5%; Average loss: 4.8994
# Iteration: 26; Percent complete: 0.5%; Average loss: 5.0734
# Iteration: 27; Percent complete: 0.5%; Average loss: 4.8771
# Iteration: 28; Percent complete: 0.6%; Average loss: 4.7149
# Iteration: 29; Percent complete: 0.6%; Average loss: 4.6870
# Iteration: 30; Percent complete: 0.6%; Average loss: 4.8350
# Iteration: 31; Percent complete: 0.6%; Average loss: 4.8046
# Iteration: 32; Percent complete: 0.6%; Average loss: 4.7758
# Iteration: 33; Percent complete: 0.7%; Average loss: 4.7873
# Iteration: 34; Percent complete: 0.7%; Average loss: 4.8326
# Iteration: 35; Percent complete: 0.7%; Average loss: 4.5247
# Iteration: 36; Percent complete: 0.7%; Average loss: 4.8561
# Iteration: 37; Percent complete: 0.7%; Average loss: 4.8345
# Iteration: 38; Percent complete: 0.8%; Average loss: 4.5283
# Iteration: 39; Percent complete: 0.8%; Average loss: 4.7331
# Iteration: 40; Percent complete: 0.8%; Average loss: 4.7158
# Iteration: 41; Percent complete: 0.8%; Average loss: 4.8052
# Iteration: 42; Percent complete: 0.8%; Average loss: 4.4751
# Iteration: 43; Percent complete: 0.9%; Average loss: 4.7047
# Iteration: 44; Percent complete: 0.9%; Average loss: 4.5384
# Iteration: 45; Percent complete: 0.9%; Average loss: 4.6262
# Iteration: 46; Percent complete: 0.9%; Average loss: 4.8071
# Iteration: 47; Percent complete: 0.9%; Average loss: 4.6003
# Iteration: 48; Percent complete: 1.0%; Average loss: 4.8860
# Iteration: 49; Percent complete: 1.0%; Average loss: 4.6729
# Iteration: 50; Percent complete: 1.0%; Average loss: 4.6140
# Iteration: 51; Percent complete: 1.0%; Average loss: 4.6082
# Iteration: 52; Percent complete: 1.0%; Average loss: 4.5202
# Iteration: 53; Percent complete: 1.1%; Average loss: 4.6215
# Iteration: 54; Percent complete: 1.1%; Average loss: 4.5646
# Iteration: 55; Percent complete: 1.1%; Average loss: 4.5829
# Iteration: 56; Percent complete: 1.1%; Average loss: 4.6584
# Iteration: 57; Percent complete: 1.1%; Average loss: 4.7504
# Iteration: 58; Percent complete: 1.2%; Average loss: 4.7559
# Iteration: 59; Percent complete: 1.2%; Average loss: 4.6911
# Iteration: 60; Percent complete: 1.2%; Average loss: 4.5985
# Iteration: 61; Percent complete: 1.2%; Average loss: 4.6058
# Iteration: 62; Percent complete: 1.2%; Average loss: 4.4472
# Iteration: 63; Percent complete: 1.3%; Average loss: 4.4806
# Iteration: 64; Percent complete: 1.3%; Average loss: 4.6410
# Iteration: 65; Percent complete: 1.3%; Average loss: 4.4798
# Iteration: 66; Percent complete: 1.3%; Average loss: 4.5980
# Iteration: 67; Percent complete: 1.3%; Average loss: 4.7253
# Iteration: 68; Percent complete: 1.4%; Average loss: 4.3107
# Iteration: 69; Percent complete: 1.4%; Average loss: 4.5620
# Iteration: 70; Percent complete: 1.4%; Average loss: 4.7703
# Iteration: 71; Percent complete: 1.4%; Average loss: 4.7272
# Iteration: 72; Percent complete: 1.4%; Average loss: 4.3130
# Iteration: 73; Percent complete: 1.5%; Average loss: 4.7523
# Iteration: 74; Percent complete: 1.5%; Average loss: 4.3765
# Iteration: 75; Percent complete: 1.5%; Average loss: 4.1868
# Iteration: 76; Percent complete: 1.5%; Average loss: 4.5599
# Iteration: 77; Percent complete: 1.5%; Average loss: 4.6209
# Iteration: 78; Percent complete: 1.6%; Average loss: 4.3690
# Iteration: 79; Percent complete: 1.6%; Average loss: 4.5042
# Iteration: 80; Percent complete: 1.6%; Average loss: 4.3694
# Iteration: 81; Percent complete: 1.6%; Average loss: 4.4693
# Iteration: 82; Percent complete: 1.6%; Average loss: 4.4273
# Iteration: 83; Percent complete: 1.7%; Average loss: 4.4887
# Iteration: 84; Percent complete: 1.7%; Average loss: 4.3922
# Iteration: 85; Percent complete: 1.7%; Average loss: 4.3337
# Iteration: 86; Percent complete: 1.7%; Average loss: 4.4844
# Iteration: 87; Percent complete: 1.7%; Average loss: 4.5361
# Iteration: 88; Percent complete: 1.8%; Average loss: 4.6858
# Iteration: 89; Percent complete: 1.8%; Average loss: 4.4059
# Iteration: 90; Percent complete: 1.8%; Average loss: 4.4893
# Iteration: 91; Percent complete: 1.8%; Average loss: 4.5022
# Iteration: 92; Percent complete: 1.8%; Average loss: 4.4010
# Iteration: 93; Percent complete: 1.9%; Average loss: 4.4314
# Iteration: 94; Percent complete: 1.9%; Average loss: 4.3837
# Iteration: 95; Percent complete: 1.9%; Average loss: 4.4954
# Iteration: 96; Percent complete: 1.9%; Average loss: 4.5162
# Iteration: 97; Percent complete: 1.9%; Average loss: 4.4372
# Iteration: 98; Percent complete: 2.0%; Average loss: 4.3140
# Iteration: 99; Percent complete: 2.0%; Average loss: 4.4601
# Iteration: 100; Percent complete: 2.0%; Average loss: 4.2852
# Iteration: 101; Percent complete: 2.0%; Average loss: 4.7494
# Iteration: 102; Percent complete: 2.0%; Average loss: 4.6164
# Iteration: 103; Percent complete: 2.1%; Average loss: 4.3804
# Iteration: 104; Percent complete: 2.1%; Average loss: 4.4398
# Iteration: 105; Percent complete: 2.1%; Average loss: 4.5293
# Iteration: 106; Percent complete: 2.1%; Average loss: 4.3859
# Iteration: 107; Percent complete: 2.1%; Average loss: 4.2089
# Iteration: 108; Percent complete: 2.2%; Average loss: 4.2012
# Iteration: 109; Percent complete: 2.2%; Average loss: 4.2764
# Iteration: 110; Percent complete: 2.2%; Average loss: 4.4085
# Iteration: 111; Percent complete: 2.2%; Average loss: 4.5497
# Iteration: 112; Percent complete: 2.2%; Average loss: 4.3065
# Iteration: 113; Percent complete: 2.3%; Average loss: 4.5540
# Iteration: 114; Percent complete: 2.3%; Average loss: 4.4564
# Iteration: 115; Percent complete: 2.3%; Average loss: 4.4567
# Iteration: 116; Percent complete: 2.3%; Average loss: 4.3352
# Iteration: 117; Percent complete: 2.3%; Average loss: 4.1642
# Iteration: 118; Percent complete: 2.4%; Average loss: 4.2595
# Iteration: 119; Percent complete: 2.4%; Average loss: 4.3703
# Iteration: 120; Percent complete: 2.4%; Average loss: 4.1145
# Iteration: 121; Percent complete: 2.4%; Average loss: 4.3191
# Iteration: 122; Percent complete: 2.4%; Average loss: 4.3022
# Iteration: 123; Percent complete: 2.5%; Average loss: 4.4019
# Iteration: 124; Percent complete: 2.5%; Average loss: 4.3683
# Iteration: 125; Percent complete: 2.5%; Average loss: 4.3250
# Iteration: 126; Percent complete: 2.5%; Average loss: 3.9949
# Iteration: 127; Percent complete: 2.5%; Average loss: 4.2565
# Iteration: 128; Percent complete: 2.6%; Average loss: 4.1499
# Iteration: 129; Percent complete: 2.6%; Average loss: 4.3470
# Iteration: 130; Percent complete: 2.6%; Average loss: 4.3630
# Iteration: 131; Percent complete: 2.6%; Average loss: 4.3844
# Iteration: 132; Percent complete: 2.6%; Average loss: 4.2966
# Iteration: 133; Percent complete: 2.7%; Average loss: 4.2597
# Iteration: 134; Percent complete: 2.7%; Average loss: 4.4529
# Iteration: 135; Percent complete: 2.7%; Average loss: 4.1527
# Iteration: 136; Percent complete: 2.7%; Average loss: 4.2879
# Iteration: 137; Percent complete: 2.7%; Average loss: 4.1890
# Iteration: 138; Percent complete: 2.8%; Average loss: 4.2523
# Iteration: 139; Percent complete: 2.8%; Average loss: 4.2978
# Iteration: 140; Percent complete: 2.8%; Average loss: 4.1698
# Iteration: 141; Percent complete: 2.8%; Average loss: 4.2905
# Iteration: 142; Percent complete: 2.8%; Average loss: 4.3467
# Iteration: 143; Percent complete: 2.9%; Average loss: 4.2255
# Iteration: 144; Percent complete: 2.9%; Average loss: 4.1400
# Iteration: 145; Percent complete: 2.9%; Average loss: 4.0830
# Iteration: 146; Percent complete: 2.9%; Average loss: 4.1204
# Iteration: 147; Percent complete: 2.9%; Average loss: 4.1784
# Iteration: 148; Percent complete: 3.0%; Average loss: 4.1256
# Iteration: 149; Percent complete: 3.0%; Average loss: 4.3997
# Iteration: 150; Percent complete: 3.0%; Average loss: 4.1545
# Iteration: 151; Percent complete: 3.0%; Average loss: 4.4894
# Iteration: 152; Percent complete: 3.0%; Average loss: 4.2849
# Iteration: 153; Percent complete: 3.1%; Average loss: 4.2954
# Iteration: 154; Percent complete: 3.1%; Average loss: 4.1579
# Iteration: 155; Percent complete: 3.1%; Average loss: 4.1806
# Iteration: 156; Percent complete: 3.1%; Average loss: 4.2440
# Iteration: 157; Percent complete: 3.1%; Average loss: 4.1938
# Iteration: 158; Percent complete: 3.2%; Average loss: 4.1640
# Iteration: 159; Percent complete: 3.2%; Average loss: 4.4658
# Iteration: 160; Percent complete: 3.2%; Average loss: 4.4082
# Iteration: 161; Percent complete: 3.2%; Average loss: 4.2953
# Iteration: 162; Percent complete: 3.2%; Average loss: 4.3793
# Iteration: 163; Percent complete: 3.3%; Average loss: 4.1657
# Iteration: 164; Percent complete: 3.3%; Average loss: 4.2039
# Iteration: 165; Percent complete: 3.3%; Average loss: 4.3804
# Iteration: 166; Percent complete: 3.3%; Average loss: 4.2248
# Iteration: 167; Percent complete: 3.3%; Average loss: 4.3676
# Iteration: 168; Percent complete: 3.4%; Average loss: 4.0548
# Iteration: 169; Percent complete: 3.4%; Average loss: 4.1736
# Iteration: 170; Percent complete: 3.4%; Average loss: 3.8213
# Iteration: 171; Percent complete: 3.4%; Average loss: 4.1032
# Iteration: 172; Percent complete: 3.4%; Average loss: 4.0592
# Iteration: 173; Percent complete: 3.5%; Average loss: 4.1060
# Iteration: 174; Percent complete: 3.5%; Average loss: 4.1975
# Iteration: 175; Percent complete: 3.5%; Average loss: 3.9303
# Iteration: 176; Percent complete: 3.5%; Average loss: 4.1775
# Iteration: 177; Percent complete: 3.5%; Average loss: 4.2234
# Iteration: 178; Percent complete: 3.6%; Average loss: 4.3511
# Iteration: 179; Percent complete: 3.6%; Average loss: 3.9515
# Iteration: 180; Percent complete: 3.6%; Average loss: 4.2110
# Iteration: 181; Percent complete: 3.6%; Average loss: 3.8086
# Iteration: 182; Percent complete: 3.6%; Average loss: 4.2365
# Iteration: 183; Percent complete: 3.7%; Average loss: 3.9199
# Iteration: 184; Percent complete: 3.7%; Average loss: 4.1775
# Iteration: 185; Percent complete: 3.7%; Average loss: 4.0964
# Iteration: 186; Percent complete: 3.7%; Average loss: 4.0012
# Iteration: 187; Percent complete: 3.7%; Average loss: 4.2354
# Iteration: 188; Percent complete: 3.8%; Average loss: 4.0467
# Iteration: 189; Percent complete: 3.8%; Average loss: 4.0434
# Iteration: 190; Percent complete: 3.8%; Average loss: 4.3390
# Iteration: 191; Percent complete: 3.8%; Average loss: 4.2086
# Iteration: 192; Percent complete: 3.8%; Average loss: 3.8056
# Iteration: 193; Percent complete: 3.9%; Average loss: 4.4321
# Iteration: 194; Percent complete: 3.9%; Average loss: 4.2172
# Iteration: 195; Percent complete: 3.9%; Average loss: 3.8775
# Iteration: 196; Percent complete: 3.9%; Average loss: 4.0609
# Iteration: 197; Percent complete: 3.9%; Average loss: 3.8555
# Iteration: 198; Percent complete: 4.0%; Average loss: 4.2718
# Iteration: 199; Percent complete: 4.0%; Average loss: 3.8650
# Iteration: 200; Percent complete: 4.0%; Average loss: 4.1415
# Iteration: 201; Percent complete: 4.0%; Average loss: 3.8877
# Iteration: 202; Percent complete: 4.0%; Average loss: 3.7870
# Iteration: 203; Percent complete: 4.1%; Average loss: 3.7706
# Iteration: 204; Percent complete: 4.1%; Average loss: 3.8053
# Iteration: 205; Percent complete: 4.1%; Average loss: 4.2209
# Iteration: 206; Percent complete: 4.1%; Average loss: 3.9942
# Iteration: 207; Percent complete: 4.1%; Average loss: 3.9876
# Iteration: 208; Percent complete: 4.2%; Average loss: 4.3529
# Iteration: 209; Percent complete: 4.2%; Average loss: 3.9926
# Iteration: 210; Percent complete: 4.2%; Average loss: 4.2725
# Iteration: 211; Percent complete: 4.2%; Average loss: 4.2073
# Iteration: 212; Percent complete: 4.2%; Average loss: 4.1536
# Iteration: 213; Percent complete: 4.3%; Average loss: 4.1123
# Iteration: 214; Percent complete: 4.3%; Average loss: 3.7668
# Iteration: 215; Percent complete: 4.3%; Average loss: 3.9971
# Iteration: 216; Percent complete: 4.3%; Average loss: 4.3219
# Iteration: 217; Percent complete: 4.3%; Average loss: 4.0925
# Iteration: 218; Percent complete: 4.4%; Average loss: 3.9683
# Iteration: 219; Percent complete: 4.4%; Average loss: 3.9911
# Iteration: 220; Percent complete: 4.4%; Average loss: 3.9705
# Iteration: 221; Percent complete: 4.4%; Average loss: 3.9648
# Iteration: 222; Percent complete: 4.4%; Average loss: 3.7874
# Iteration: 223; Percent complete: 4.5%; Average loss: 4.2181
# Iteration: 224; Percent complete: 4.5%; Average loss: 4.0242
# Iteration: 225; Percent complete: 4.5%; Average loss: 3.8084
# Iteration: 226; Percent complete: 4.5%; Average loss: 4.1263
# Iteration: 227; Percent complete: 4.5%; Average loss: 4.1307
# Iteration: 228; Percent complete: 4.6%; Average loss: 4.1492
# Iteration: 229; Percent complete: 4.6%; Average loss: 4.0144
# Iteration: 230; Percent complete: 4.6%; Average loss: 3.9102
# Iteration: 231; Percent complete: 4.6%; Average loss: 4.1284
# Iteration: 232; Percent complete: 4.6%; Average loss: 3.8219
# Iteration: 233; Percent complete: 4.7%; Average loss: 3.8113
# Iteration: 234; Percent complete: 4.7%; Average loss: 3.8044
# Iteration: 235; Percent complete: 4.7%; Average loss: 3.8942
# Iteration: 236; Percent complete: 4.7%; Average loss: 3.9668
# Iteration: 237; Percent complete: 4.7%; Average loss: 4.1137
# Iteration: 238; Percent complete: 4.8%; Average loss: 4.0637
# Iteration: 239; Percent complete: 4.8%; Average loss: 3.9338
# Iteration: 240; Percent complete: 4.8%; Average loss: 3.8939
# Iteration: 241; Percent complete: 4.8%; Average loss: 4.0522
# Iteration: 242; Percent complete: 4.8%; Average loss: 3.8861
# Iteration: 243; Percent complete: 4.9%; Average loss: 4.2759
# Iteration: 244; Percent complete: 4.9%; Average loss: 4.1414
# Iteration: 245; Percent complete: 4.9%; Average loss: 4.0828
# Iteration: 246; Percent complete: 4.9%; Average loss: 4.0431
# Iteration: 247; Percent complete: 4.9%; Average loss: 3.9875
# Iteration: 248; Percent complete: 5.0%; Average loss: 4.0552
# Iteration: 249; Percent complete: 5.0%; Average loss: 3.9264
# Iteration: 250; Percent complete: 5.0%; Average loss: 4.1359
# Iteration: 251; Percent complete: 5.0%; Average loss: 3.8627
# Iteration: 252; Percent complete: 5.0%; Average loss: 3.9136
# Iteration: 253; Percent complete: 5.1%; Average loss: 3.6427
# Iteration: 254; Percent complete: 5.1%; Average loss: 3.7330
# Iteration: 255; Percent complete: 5.1%; Average loss: 3.8609
# Iteration: 256; Percent complete: 5.1%; Average loss: 3.9703
# Iteration: 257; Percent complete: 5.1%; Average loss: 3.9178
# Iteration: 258; Percent complete: 5.2%; Average loss: 4.1665
# Iteration: 259; Percent complete: 5.2%; Average loss: 4.0056
# Iteration: 260; Percent complete: 5.2%; Average loss: 3.9053
# Iteration: 261; Percent complete: 5.2%; Average loss: 3.8398
# Iteration: 262; Percent complete: 5.2%; Average loss: 3.7609
# Iteration: 263; Percent complete: 5.3%; Average loss: 3.8449
# Iteration: 264; Percent complete: 5.3%; Average loss: 3.9868
# Iteration: 265; Percent complete: 5.3%; Average loss: 3.6126
# Iteration: 266; Percent complete: 5.3%; Average loss: 4.0590
# Iteration: 267; Percent complete: 5.3%; Average loss: 3.8070
# Iteration: 268; Percent complete: 5.4%; Average loss: 4.1052
# Iteration: 269; Percent complete: 5.4%; Average loss: 3.8581
# Iteration: 270; Percent complete: 5.4%; Average loss: 3.7767
# Iteration: 271; Percent complete: 5.4%; Average loss: 3.9087
# Iteration: 272; Percent complete: 5.4%; Average loss: 3.9940
# Iteration: 273; Percent complete: 5.5%; Average loss: 3.8804
# Iteration: 274; Percent complete: 5.5%; Average loss: 3.8708
# Iteration: 275; Percent complete: 5.5%; Average loss: 3.8401
# Iteration: 276; Percent complete: 5.5%; Average loss: 4.0942
# Iteration: 277; Percent complete: 5.5%; Average loss: 3.7468
# Iteration: 278; Percent complete: 5.6%; Average loss: 3.9002
# Iteration: 279; Percent complete: 5.6%; Average loss: 3.7720
# Iteration: 280; Percent complete: 5.6%; Average loss: 4.0790
# Iteration: 281; Percent complete: 5.6%; Average loss: 4.0439
# Iteration: 282; Percent complete: 5.6%; Average loss: 3.8432
# Iteration: 283; Percent complete: 5.7%; Average loss: 3.9025
# Iteration: 284; Percent complete: 5.7%; Average loss: 3.8963
# Iteration: 285; Percent complete: 5.7%; Average loss: 4.0714
# Iteration: 286; Percent complete: 5.7%; Average loss: 4.1294
# Iteration: 287; Percent complete: 5.7%; Average loss: 3.9920
# Iteration: 288; Percent complete: 5.8%; Average loss: 3.8476
# Iteration: 289; Percent complete: 5.8%; Average loss: 3.9075
# Iteration: 290; Percent complete: 5.8%; Average loss: 3.8914
# Iteration: 291; Percent complete: 5.8%; Average loss: 3.9404
# Iteration: 292; Percent complete: 5.8%; Average loss: 3.9863
# Iteration: 293; Percent complete: 5.9%; Average loss: 4.0557
# Iteration: 294; Percent complete: 5.9%; Average loss: 4.0272
# Iteration: 295; Percent complete: 5.9%; Average loss: 3.9203
# Iteration: 296; Percent complete: 5.9%; Average loss: 4.1126
# Iteration: 297; Percent complete: 5.9%; Average loss: 3.7395
# Iteration: 298; Percent complete: 6.0%; Average loss: 4.1185
# Iteration: 299; Percent complete: 6.0%; Average loss: 3.8974
# Iteration: 300; Percent complete: 6.0%; Average loss: 4.0103
# Iteration: 301; Percent complete: 6.0%; Average loss: 3.7518
# Iteration: 302; Percent complete: 6.0%; Average loss: 3.8833
# Iteration: 303; Percent complete: 6.1%; Average loss: 3.8695
# Iteration: 304; Percent complete: 6.1%; Average loss: 3.8015
# Iteration: 305; Percent complete: 6.1%; Average loss: 4.2057
# Iteration: 306; Percent complete: 6.1%; Average loss: 3.7446
# Iteration: 307; Percent complete: 6.1%; Average loss: 3.9279
# Iteration: 308; Percent complete: 6.2%; Average loss: 3.9263
# Iteration: 309; Percent complete: 6.2%; Average loss: 3.7282
# Iteration: 310; Percent complete: 6.2%; Average loss: 3.7335
# Iteration: 311; Percent complete: 6.2%; Average loss: 3.7619
# Iteration: 312; Percent complete: 6.2%; Average loss: 3.9535
# Iteration: 313; Percent complete: 6.3%; Average loss: 4.0849
# Iteration: 314; Percent complete: 6.3%; Average loss: 4.0331
# Iteration: 315; Percent complete: 6.3%; Average loss: 3.7420
# Iteration: 316; Percent complete: 6.3%; Average loss: 3.6314
# Iteration: 317; Percent complete: 6.3%; Average loss: 3.7724
# Iteration: 318; Percent complete: 6.4%; Average loss: 3.9680
# Iteration: 319; Percent complete: 6.4%; Average loss: 3.7706
# Iteration: 320; Percent complete: 6.4%; Average loss: 3.8198
# Iteration: 321; Percent complete: 6.4%; Average loss: 3.8270
# Iteration: 322; Percent complete: 6.4%; Average loss: 3.7234
# Iteration: 323; Percent complete: 6.5%; Average loss: 4.0138
# Iteration: 324; Percent complete: 6.5%; Average loss: 4.0537
# Iteration: 325; Percent complete: 6.5%; Average loss: 3.8098
# Iteration: 326; Percent complete: 6.5%; Average loss: 4.0404
# Iteration: 327; Percent complete: 6.5%; Average loss: 3.7138
# Iteration: 328; Percent complete: 6.6%; Average loss: 3.8726
# Iteration: 329; Percent complete: 6.6%; Average loss: 3.7968
# Iteration: 330; Percent complete: 6.6%; Average loss: 3.9435
# Iteration: 331; Percent complete: 6.6%; Average loss: 4.1177
# Iteration: 332; Percent complete: 6.6%; Average loss: 3.7718
# Iteration: 333; Percent complete: 6.7%; Average loss: 3.8927
# Iteration: 334; Percent complete: 6.7%; Average loss: 3.7955
# Iteration: 335; Percent complete: 6.7%; Average loss: 3.8947
# Iteration: 336; Percent complete: 6.7%; Average loss: 3.8839
# Iteration: 337; Percent complete: 6.7%; Average loss: 3.8875
# Iteration: 338; Percent complete: 6.8%; Average loss: 3.9166
# Iteration: 339; Percent complete: 6.8%; Average loss: 3.8662
# Iteration: 340; Percent complete: 6.8%; Average loss: 3.9502
# Iteration: 341; Percent complete: 6.8%; Average loss: 3.8759
# Iteration: 342; Percent complete: 6.8%; Average loss: 4.0453
# Iteration: 343; Percent complete: 6.9%; Average loss: 3.8563
# Iteration: 344; Percent complete: 6.9%; Average loss: 3.9149
# Iteration: 345; Percent complete: 6.9%; Average loss: 3.5615
# Iteration: 346; Percent complete: 6.9%; Average loss: 3.7547
# Iteration: 347; Percent complete: 6.9%; Average loss: 3.9494
# Iteration: 348; Percent complete: 7.0%; Average loss: 4.0932
# Iteration: 349; Percent complete: 7.0%; Average loss: 4.0418
# Iteration: 350; Percent complete: 7.0%; Average loss: 3.6693
# Iteration: 351; Percent complete: 7.0%; Average loss: 3.8891
# Iteration: 352; Percent complete: 7.0%; Average loss: 3.8470
# Iteration: 353; Percent complete: 7.1%; Average loss: 3.9648
# Iteration: 354; Percent complete: 7.1%; Average loss: 3.8641
# Iteration: 355; Percent complete: 7.1%; Average loss: 3.8968
# Iteration: 356; Percent complete: 7.1%; Average loss: 3.6928
# Iteration: 357; Percent complete: 7.1%; Average loss: 4.0554
# Iteration: 358; Percent complete: 7.2%; Average loss: 3.7824
# Iteration: 359; Percent complete: 7.2%; Average loss: 4.0301
# Iteration: 360; Percent complete: 7.2%; Average loss: 3.6862
# Iteration: 361; Percent complete: 7.2%; Average loss: 3.9639
# Iteration: 362; Percent complete: 7.2%; Average loss: 3.9186
# Iteration: 363; Percent complete: 7.3%; Average loss: 3.6592
# Iteration: 364; Percent complete: 7.3%; Average loss: 4.0294
# Iteration: 365; Percent complete: 7.3%; Average loss: 3.7536
# Iteration: 366; Percent complete: 7.3%; Average loss: 3.9900
# Iteration: 367; Percent complete: 7.3%; Average loss: 3.6888
# Iteration: 368; Percent complete: 7.4%; Average loss: 4.0117
# Iteration: 369; Percent complete: 7.4%; Average loss: 3.9408
# Iteration: 370; Percent complete: 7.4%; Average loss: 3.8021
# Iteration: 371; Percent complete: 7.4%; Average loss: 4.1245
# Iteration: 372; Percent complete: 7.4%; Average loss: 3.7967
# Iteration: 373; Percent complete: 7.5%; Average loss: 3.8807
# Iteration: 374; Percent complete: 7.5%; Average loss: 4.0518
# Iteration: 375; Percent complete: 7.5%; Average loss: 3.6530
# Iteration: 376; Percent complete: 7.5%; Average loss: 4.1592
# Iteration: 377; Percent complete: 7.5%; Average loss: 3.6101
# Iteration: 378; Percent complete: 7.6%; Average loss: 3.8304
# Iteration: 379; Percent complete: 7.6%; Average loss: 3.5488
# Iteration: 380; Percent complete: 7.6%; Average loss: 3.6935
# Iteration: 381; Percent complete: 7.6%; Average loss: 3.8025
# Iteration: 382; Percent complete: 7.6%; Average loss: 3.9166
# Iteration: 383; Percent complete: 7.7%; Average loss: 3.4700
# Iteration: 384; Percent complete: 7.7%; Average loss: 4.0885
# Iteration: 385; Percent complete: 7.7%; Average loss: 3.8128
# Iteration: 386; Percent complete: 7.7%; Average loss: 3.9860
# Iteration: 387; Percent complete: 7.7%; Average loss: 3.5711
# Iteration: 388; Percent complete: 7.8%; Average loss: 3.8117
# Iteration: 389; Percent complete: 7.8%; Average loss: 3.7517
# Iteration: 390; Percent complete: 7.8%; Average loss: 3.8505
# Iteration: 391; Percent complete: 7.8%; Average loss: 3.6787
# Iteration: 392; Percent complete: 7.8%; Average loss: 4.0092
# Iteration: 393; Percent complete: 7.9%; Average loss: 3.6599
# Iteration: 394; Percent complete: 7.9%; Average loss: 3.9564
# Iteration: 395; Percent complete: 7.9%; Average loss: 3.6051
# Iteration: 396; Percent complete: 7.9%; Average loss: 3.6927
# Iteration: 397; Percent complete: 7.9%; Average loss: 3.7692
# Iteration: 398; Percent complete: 8.0%; Average loss: 3.8388
# Iteration: 399; Percent complete: 8.0%; Average loss: 3.5797
# Iteration: 400; Percent complete: 8.0%; Average loss: 3.9272
# Iteration: 401; Percent complete: 8.0%; Average loss: 3.9728
# Iteration: 402; Percent complete: 8.0%; Average loss: 4.0015
# Iteration: 403; Percent complete: 8.1%; Average loss: 3.8996
# Iteration: 404; Percent complete: 8.1%; Average loss: 3.9461
# Iteration: 405; Percent complete: 8.1%; Average loss: 3.8557
# Iteration: 406; Percent complete: 8.1%; Average loss: 3.8019
# Iteration: 407; Percent complete: 8.1%; Average loss: 3.6527
# Iteration: 408; Percent complete: 8.2%; Average loss: 3.8346
# Iteration: 409; Percent complete: 8.2%; Average loss: 3.6784
# Iteration: 410; Percent complete: 8.2%; Average loss: 4.0661
# Iteration: 411; Percent complete: 8.2%; Average loss: 3.7656
# Iteration: 412; Percent complete: 8.2%; Average loss: 3.6840
# Iteration: 413; Percent complete: 8.3%; Average loss: 3.8496
# Iteration: 414; Percent complete: 8.3%; Average loss: 3.6790
# Iteration: 415; Percent complete: 8.3%; Average loss: 3.9698
# Iteration: 416; Percent complete: 8.3%; Average loss: 3.6625
# Iteration: 417; Percent complete: 8.3%; Average loss: 3.9013
# Iteration: 418; Percent complete: 8.4%; Average loss: 3.7991
# Iteration: 419; Percent complete: 8.4%; Average loss: 3.6141
# Iteration: 420; Percent complete: 8.4%; Average loss: 3.7819
# Iteration: 421; Percent complete: 8.4%; Average loss: 3.9257
# Iteration: 422; Percent complete: 8.4%; Average loss: 3.7557
# Iteration: 423; Percent complete: 8.5%; Average loss: 3.8069
# Iteration: 424; Percent complete: 8.5%; Average loss: 3.7394
# Iteration: 425; Percent complete: 8.5%; Average loss: 3.7198
# Iteration: 426; Percent complete: 8.5%; Average loss: 3.9795
# Iteration: 427; Percent complete: 8.5%; Average loss: 3.7464
# Iteration: 428; Percent complete: 8.6%; Average loss: 3.5485
# Iteration: 429; Percent complete: 8.6%; Average loss: 3.9788
# Iteration: 430; Percent complete: 8.6%; Average loss: 3.9863
# Iteration: 431; Percent complete: 8.6%; Average loss: 3.6129
# Iteration: 432; Percent complete: 8.6%; Average loss: 3.6030
# Iteration: 433; Percent complete: 8.7%; Average loss: 3.9831
# Iteration: 434; Percent complete: 8.7%; Average loss: 3.8150
# Iteration: 435; Percent complete: 8.7%; Average loss: 3.5877
# Iteration: 436; Percent complete: 8.7%; Average loss: 3.8456
# Iteration: 437; Percent complete: 8.7%; Average loss: 3.5518
# Iteration: 438; Percent complete: 8.8%; Average loss: 3.8520
# Iteration: 439; Percent complete: 8.8%; Average loss: 3.6421
# Iteration: 440; Percent complete: 8.8%; Average loss: 3.7955
# Iteration: 441; Percent complete: 8.8%; Average loss: 3.8662
# Iteration: 442; Percent complete: 8.8%; Average loss: 3.5706
# Iteration: 443; Percent complete: 8.9%; Average loss: 3.8253
# Iteration: 444; Percent complete: 8.9%; Average loss: 3.7867
# Iteration: 445; Percent complete: 8.9%; Average loss: 3.4822
# Iteration: 446; Percent complete: 8.9%; Average loss: 3.4110
# Iteration: 447; Percent complete: 8.9%; Average loss: 3.8351
# Iteration: 448; Percent complete: 9.0%; Average loss: 3.7595
# Iteration: 449; Percent complete: 9.0%; Average loss: 3.6988
# Iteration: 450; Percent complete: 9.0%; Average loss: 3.3435
# Iteration: 451; Percent complete: 9.0%; Average loss: 3.7198
# Iteration: 452; Percent complete: 9.0%; Average loss: 3.4998
# Iteration: 453; Percent complete: 9.1%; Average loss: 3.9154
# Iteration: 454; Percent complete: 9.1%; Average loss: 3.9707
# Iteration: 455; Percent complete: 9.1%; Average loss: 3.5529
# Iteration: 456; Percent complete: 9.1%; Average loss: 3.8720
# Iteration: 457; Percent complete: 9.1%; Average loss: 3.8212
# Iteration: 458; Percent complete: 9.2%; Average loss: 3.8196
# Iteration: 459; Percent complete: 9.2%; Average loss: 3.8040
# Iteration: 460; Percent complete: 9.2%; Average loss: 3.7727
# Iteration: 461; Percent complete: 9.2%; Average loss: 3.7360
# Iteration: 462; Percent complete: 9.2%; Average loss: 3.6339
# Iteration: 463; Percent complete: 9.3%; Average loss: 3.8099
# Iteration: 464; Percent complete: 9.3%; Average loss: 3.7419
# Iteration: 465; Percent complete: 9.3%; Average loss: 3.9644
# Iteration: 466; Percent complete: 9.3%; Average loss: 3.5726
# Iteration: 467; Percent complete: 9.3%; Average loss: 3.6220
# Iteration: 468; Percent complete: 9.4%; Average loss: 3.7181
# Iteration: 469; Percent complete: 9.4%; Average loss: 3.7030
# Iteration: 470; Percent complete: 9.4%; Average loss: 3.5664
# Iteration: 471; Percent complete: 9.4%; Average loss: 3.8938
# Iteration: 472; Percent complete: 9.4%; Average loss: 3.7716
# Iteration: 473; Percent complete: 9.5%; Average loss: 3.7106
# Iteration: 474; Percent complete: 9.5%; Average loss: 3.5033
# Iteration: 475; Percent complete: 9.5%; Average loss: 3.6864
# Iteration: 476; Percent complete: 9.5%; Average loss: 3.7944
# Iteration: 477; Percent complete: 9.5%; Average loss: 3.7973
# Iteration: 478; Percent complete: 9.6%; Average loss: 3.7626
# Iteration: 479; Percent complete: 9.6%; Average loss: 3.6672
# Iteration: 480; Percent complete: 9.6%; Average loss: 3.8407
# Iteration: 481; Percent complete: 9.6%; Average loss: 3.5642
# Iteration: 482; Percent complete: 9.6%; Average loss: 3.7311
# Iteration: 483; Percent complete: 9.7%; Average loss: 3.7647
# Iteration: 484; Percent complete: 9.7%; Average loss: 3.9083
# Iteration: 485; Percent complete: 9.7%; Average loss: 3.6011
# Iteration: 486; Percent complete: 9.7%; Average loss: 3.8412
# Iteration: 487; Percent complete: 9.7%; Average loss: 3.7760
# Iteration: 488; Percent complete: 9.8%; Average loss: 3.8788
# Iteration: 489; Percent complete: 9.8%; Average loss: 3.7809
# Iteration: 490; Percent complete: 9.8%; Average loss: 4.0286
# Iteration: 491; Percent complete: 9.8%; Average loss: 3.6505
# Iteration: 492; Percent complete: 9.8%; Average loss: 3.4594
# Iteration: 493; Percent complete: 9.9%; Average loss: 3.6383
# Iteration: 494; Percent complete: 9.9%; Average loss: 3.4835
# Iteration: 495; Percent complete: 9.9%; Average loss: 3.7816
# Iteration: 496; Percent complete: 9.9%; Average loss: 3.9848
# Iteration: 497; Percent complete: 9.9%; Average loss: 3.5546
# Iteration: 498; Percent complete: 10.0%; Average loss: 3.9588
# Iteration: 499; Percent complete: 10.0%; Average loss: 3.5734
# Iteration: 500; Percent complete: 10.0%; Average loss: 3.7345
# Iteration: 501; Percent complete: 10.0%; Average loss: 3.6426
# Iteration: 502; Percent complete: 10.0%; Average loss: 4.0305
# Iteration: 503; Percent complete: 10.1%; Average loss: 3.8679
# Iteration: 504; Percent complete: 10.1%; Average loss: 3.9526
# Iteration: 505; Percent complete: 10.1%; Average loss: 3.5330
# Iteration: 506; Percent complete: 10.1%; Average loss: 3.7016
# Iteration: 507; Percent complete: 10.1%; Average loss: 3.7160
# Iteration: 508; Percent complete: 10.2%; Average loss: 3.3651
# Iteration: 509; Percent complete: 10.2%; Average loss: 3.6790
# Iteration: 510; Percent complete: 10.2%; Average loss: 3.5239
# Iteration: 511; Percent complete: 10.2%; Average loss: 3.5407
# Iteration: 512; Percent complete: 10.2%; Average loss: 3.8126
# Iteration: 513; Percent complete: 10.3%; Average loss: 3.9259
# Iteration: 514; Percent complete: 10.3%; Average loss: 3.6263
# Iteration: 515; Percent complete: 10.3%; Average loss: 3.6448
# Iteration: 516; Percent complete: 10.3%; Average loss: 3.5184
# Iteration: 517; Percent complete: 10.3%; Average loss: 3.4118
# Iteration: 518; Percent complete: 10.4%; Average loss: 3.5796
# Iteration: 519; Percent complete: 10.4%; Average loss: 3.7566
# Iteration: 520; Percent complete: 10.4%; Average loss: 3.7974
# Iteration: 521; Percent complete: 10.4%; Average loss: 3.6814
# Iteration: 522; Percent complete: 10.4%; Average loss: 3.8707
# Iteration: 523; Percent complete: 10.5%; Average loss: 3.6864
# Iteration: 524; Percent complete: 10.5%; Average loss: 3.8544
# Iteration: 525; Percent complete: 10.5%; Average loss: 3.8146
# Iteration: 526; Percent complete: 10.5%; Average loss: 3.6558
# Iteration: 527; Percent complete: 10.5%; Average loss: 3.5630
# Iteration: 528; Percent complete: 10.6%; Average loss: 3.6394
# Iteration: 529; Percent complete: 10.6%; Average loss: 3.8235
# Iteration: 530; Percent complete: 10.6%; Average loss: 3.6504
# Iteration: 531; Percent complete: 10.6%; Average loss: 3.9686
# Iteration: 532; Percent complete: 10.6%; Average loss: 3.6396
# Iteration: 533; Percent complete: 10.7%; Average loss: 3.8413
# Iteration: 534; Percent complete: 10.7%; Average loss: 4.0419
# Iteration: 535; Percent complete: 10.7%; Average loss: 3.6691
# Iteration: 536; Percent complete: 10.7%; Average loss: 3.6965
# Iteration: 537; Percent complete: 10.7%; Average loss: 3.6634
# Iteration: 538; Percent complete: 10.8%; Average loss: 3.6710
# Iteration: 539; Percent complete: 10.8%; Average loss: 3.6449
# Iteration: 540; Percent complete: 10.8%; Average loss: 3.4605
# Iteration: 541; Percent complete: 10.8%; Average loss: 3.3937
# Iteration: 542; Percent complete: 10.8%; Average loss: 3.8016
# Iteration: 543; Percent complete: 10.9%; Average loss: 3.5258
# Iteration: 544; Percent complete: 10.9%; Average loss: 3.5476
# Iteration: 545; Percent complete: 10.9%; Average loss: 3.7696
# Iteration: 546; Percent complete: 10.9%; Average loss: 3.7371
# Iteration: 547; Percent complete: 10.9%; Average loss: 3.7470
# Iteration: 548; Percent complete: 11.0%; Average loss: 3.5832
# Iteration: 549; Percent complete: 11.0%; Average loss: 3.6448
# Iteration: 550; Percent complete: 11.0%; Average loss: 3.7955
# Iteration: 551; Percent complete: 11.0%; Average loss: 3.4624
# Iteration: 552; Percent complete: 11.0%; Average loss: 3.6434
# Iteration: 553; Percent complete: 11.1%; Average loss: 3.5698
# Iteration: 554; Percent complete: 11.1%; Average loss: 3.6679
# Iteration: 555; Percent complete: 11.1%; Average loss: 3.5058
# Iteration: 556; Percent complete: 11.1%; Average loss: 3.5558
# Iteration: 557; Percent complete: 11.1%; Average loss: 4.0645
# Iteration: 558; Percent complete: 11.2%; Average loss: 3.7499
# Iteration: 559; Percent complete: 11.2%; Average loss: 3.3758
# Iteration: 560; Percent complete: 11.2%; Average loss: 3.9313
# Iteration: 561; Percent complete: 11.2%; Average loss: 3.9254
# Iteration: 562; Percent complete: 11.2%; Average loss: 3.8099
# Iteration: 563; Percent complete: 11.3%; Average loss: 3.5725
# Iteration: 564; Percent complete: 11.3%; Average loss: 3.5596
# Iteration: 565; Percent complete: 11.3%; Average loss: 3.6138
# Iteration: 566; Percent complete: 11.3%; Average loss: 3.7072
# Iteration: 567; Percent complete: 11.3%; Average loss: 3.7910
# Iteration: 568; Percent complete: 11.4%; Average loss: 3.5079
# Iteration: 569; Percent complete: 11.4%; Average loss: 3.9100
# Iteration: 570; Percent complete: 11.4%; Average loss: 3.6147
# Iteration: 571; Percent complete: 11.4%; Average loss: 3.6415
# Iteration: 572; Percent complete: 11.4%; Average loss: 3.7501
# Iteration: 573; Percent complete: 11.5%; Average loss: 3.9259
# Iteration: 574; Percent complete: 11.5%; Average loss: 3.8529
# Iteration: 575; Percent complete: 11.5%; Average loss: 3.9894
# Iteration: 576; Percent complete: 11.5%; Average loss: 3.7179
# Iteration: 577; Percent complete: 11.5%; Average loss: 3.8728
# Iteration: 578; Percent complete: 11.6%; Average loss: 3.6411
# Iteration: 579; Percent complete: 11.6%; Average loss: 3.7389
# Iteration: 580; Percent complete: 11.6%; Average loss: 3.4617
# Iteration: 581; Percent complete: 11.6%; Average loss: 4.0743
# Iteration: 582; Percent complete: 11.6%; Average loss: 3.5817
# Iteration: 583; Percent complete: 11.7%; Average loss: 3.6175
# Iteration: 584; Percent complete: 11.7%; Average loss: 3.5053
# Iteration: 585; Percent complete: 11.7%; Average loss: 3.5489
# Iteration: 586; Percent complete: 11.7%; Average loss: 3.8922
# Iteration: 587; Percent complete: 11.7%; Average loss: 3.6622
# Iteration: 588; Percent complete: 11.8%; Average loss: 3.8522
# Iteration: 589; Percent complete: 11.8%; Average loss: 3.6337
# Iteration: 590; Percent complete: 11.8%; Average loss: 3.7899
# Iteration: 591; Percent complete: 11.8%; Average loss: 3.7678
# Iteration: 592; Percent complete: 11.8%; Average loss: 3.8587
# Iteration: 593; Percent complete: 11.9%; Average loss: 3.7747
# Iteration: 594; Percent complete: 11.9%; Average loss: 3.7731
# Iteration: 595; Percent complete: 11.9%; Average loss: 3.8156
# Iteration: 596; Percent complete: 11.9%; Average loss: 3.4552
# Iteration: 597; Percent complete: 11.9%; Average loss: 3.7407
# Iteration: 598; Percent complete: 12.0%; Average loss: 3.5935
# Iteration: 599; Percent complete: 12.0%; Average loss: 3.7035
# Iteration: 600; Percent complete: 12.0%; Average loss: 3.7999
# Iteration: 601; Percent complete: 12.0%; Average loss: 3.7801
# Iteration: 602; Percent complete: 12.0%; Average loss: 3.7543
# Iteration: 603; Percent complete: 12.1%; Average loss: 3.8411
# Iteration: 604; Percent complete: 12.1%; Average loss: 3.7196
# Iteration: 605; Percent complete: 12.1%; Average loss: 3.7223
# Iteration: 606; Percent complete: 12.1%; Average loss: 3.7781
# Iteration: 607; Percent complete: 12.1%; Average loss: 3.3797
# Iteration: 608; Percent complete: 12.2%; Average loss: 3.6074
# Iteration: 609; Percent complete: 12.2%; Average loss: 3.6034
# Iteration: 610; Percent complete: 12.2%; Average loss: 3.7045
# Iteration: 611; Percent complete: 12.2%; Average loss: 3.3765
# Iteration: 612; Percent complete: 12.2%; Average loss: 3.5482
# Iteration: 613; Percent complete: 12.3%; Average loss: 3.9045
# Iteration: 614; Percent complete: 12.3%; Average loss: 3.4959
# Iteration: 615; Percent complete: 12.3%; Average loss: 3.6948
# Iteration: 616; Percent complete: 12.3%; Average loss: 3.4185
# Iteration: 617; Percent complete: 12.3%; Average loss: 3.5011
# Iteration: 618; Percent complete: 12.4%; Average loss: 3.7090
# Iteration: 619; Percent complete: 12.4%; Average loss: 3.7670
# Iteration: 620; Percent complete: 12.4%; Average loss: 3.7900
# Iteration: 621; Percent complete: 12.4%; Average loss: 3.6736
# Iteration: 622; Percent complete: 12.4%; Average loss: 3.5566
# Iteration: 623; Percent complete: 12.5%; Average loss: 3.4495
# Iteration: 624; Percent complete: 12.5%; Average loss: 3.5033
# Iteration: 625; Percent complete: 12.5%; Average loss: 3.5782
# Iteration: 626; Percent complete: 12.5%; Average loss: 3.4484
# Iteration: 627; Percent complete: 12.5%; Average loss: 3.7399
# Iteration: 628; Percent complete: 12.6%; Average loss: 3.5888
# Iteration: 629; Percent complete: 12.6%; Average loss: 3.6721
# Iteration: 630; Percent complete: 12.6%; Average loss: 3.6162
# Iteration: 631; Percent complete: 12.6%; Average loss: 3.7600
# Iteration: 632; Percent complete: 12.6%; Average loss: 3.3855
# Iteration: 633; Percent complete: 12.7%; Average loss: 3.5512
# Iteration: 634; Percent complete: 12.7%; Average loss: 3.6055
# Iteration: 635; Percent complete: 12.7%; Average loss: 3.5899
# Iteration: 636; Percent complete: 12.7%; Average loss: 3.8409
# Iteration: 637; Percent complete: 12.7%; Average loss: 3.4875
# Iteration: 638; Percent complete: 12.8%; Average loss: 3.8451
# Iteration: 639; Percent complete: 12.8%; Average loss: 3.4962
# Iteration: 640; Percent complete: 12.8%; Average loss: 3.5504
# Iteration: 641; Percent complete: 12.8%; Average loss: 3.5733
# Iteration: 642; Percent complete: 12.8%; Average loss: 3.7025
# Iteration: 643; Percent complete: 12.9%; Average loss: 3.7074
# Iteration: 644; Percent complete: 12.9%; Average loss: 3.7924
# Iteration: 645; Percent complete: 12.9%; Average loss: 3.3829
# Iteration: 646; Percent complete: 12.9%; Average loss: 3.6004
# Iteration: 647; Percent complete: 12.9%; Average loss: 3.3277
# Iteration: 648; Percent complete: 13.0%; Average loss: 3.6302
# Iteration: 649; Percent complete: 13.0%; Average loss: 3.8327
# Iteration: 650; Percent complete: 13.0%; Average loss: 3.3147
# Iteration: 651; Percent complete: 13.0%; Average loss: 3.8216
# Iteration: 652; Percent complete: 13.0%; Average loss: 3.6415
# Iteration: 653; Percent complete: 13.1%; Average loss: 3.6688
# Iteration: 654; Percent complete: 13.1%; Average loss: 3.6352
# Iteration: 655; Percent complete: 13.1%; Average loss: 3.5843
# Iteration: 656; Percent complete: 13.1%; Average loss: 3.6367
# Iteration: 657; Percent complete: 13.1%; Average loss: 3.4953
# Iteration: 658; Percent complete: 13.2%; Average loss: 3.6249
# Iteration: 659; Percent complete: 13.2%; Average loss: 3.5363
# Iteration: 660; Percent complete: 13.2%; Average loss: 3.6096
# Iteration: 661; Percent complete: 13.2%; Average loss: 3.4653
# Iteration: 662; Percent complete: 13.2%; Average loss: 3.5910
# Iteration: 663; Percent complete: 13.3%; Average loss: 3.6879
# Iteration: 664; Percent complete: 13.3%; Average loss: 3.6743
# Iteration: 665; Percent complete: 13.3%; Average loss: 3.4718
# Iteration: 666; Percent complete: 13.3%; Average loss: 3.6162
# Iteration: 667; Percent complete: 13.3%; Average loss: 3.8717
# Iteration: 668; Percent complete: 13.4%; Average loss: 3.7385
# Iteration: 669; Percent complete: 13.4%; Average loss: 3.8154
# Iteration: 670; Percent complete: 13.4%; Average loss: 3.6283
# Iteration: 671; Percent complete: 13.4%; Average loss: 3.8486
# Iteration: 672; Percent complete: 13.4%; Average loss: 3.7253
# Iteration: 673; Percent complete: 13.5%; Average loss: 3.5156
# Iteration: 674; Percent complete: 13.5%; Average loss: 3.6338
# Iteration: 675; Percent complete: 13.5%; Average loss: 3.4426
# Iteration: 676; Percent complete: 13.5%; Average loss: 3.8013
# Iteration: 677; Percent complete: 13.5%; Average loss: 3.6382
# Iteration: 678; Percent complete: 13.6%; Average loss: 3.5293
# Iteration: 679; Percent complete: 13.6%; Average loss: 3.6840
# Iteration: 680; Percent complete: 13.6%; Average loss: 3.6876
# Iteration: 681; Percent complete: 13.6%; Average loss: 3.6280
# Iteration: 682; Percent complete: 13.6%; Average loss: 3.4040
# Iteration: 683; Percent complete: 13.7%; Average loss: 3.2252
# Iteration: 684; Percent complete: 13.7%; Average loss: 3.6612
# Iteration: 685; Percent complete: 13.7%; Average loss: 3.7093
# Iteration: 686; Percent complete: 13.7%; Average loss: 3.6637
# Iteration: 687; Percent complete: 13.7%; Average loss: 3.6771
# Iteration: 688; Percent complete: 13.8%; Average loss: 3.5251
# Iteration: 689; Percent complete: 13.8%; Average loss: 3.6490
# Iteration: 690; Percent complete: 13.8%; Average loss: 3.4329
# Iteration: 691; Percent complete: 13.8%; Average loss: 4.0202
# Iteration: 692; Percent complete: 13.8%; Average loss: 3.8268
# Iteration: 693; Percent complete: 13.9%; Average loss: 3.5330
# Iteration: 694; Percent complete: 13.9%; Average loss: 3.7324
# Iteration: 695; Percent complete: 13.9%; Average loss: 3.7383
# Iteration: 696; Percent complete: 13.9%; Average loss: 3.5906
# Iteration: 697; Percent complete: 13.9%; Average loss: 3.5671
# Iteration: 698; Percent complete: 14.0%; Average loss: 3.6177
# Iteration: 699; Percent complete: 14.0%; Average loss: 3.5840
# Iteration: 700; Percent complete: 14.0%; Average loss: 3.6705
# Iteration: 701; Percent complete: 14.0%; Average loss: 3.3593
# Iteration: 702; Percent complete: 14.0%; Average loss: 3.6645
# Iteration: 703; Percent complete: 14.1%; Average loss: 4.0004
# Iteration: 704; Percent complete: 14.1%; Average loss: 3.4648
# Iteration: 705; Percent complete: 14.1%; Average loss: 3.4134
# Iteration: 706; Percent complete: 14.1%; Average loss: 3.7522
# Iteration: 707; Percent complete: 14.1%; Average loss: 3.5420
# Iteration: 708; Percent complete: 14.2%; Average loss: 3.4758
# Iteration: 709; Percent complete: 14.2%; Average loss: 3.8035
# Iteration: 710; Percent complete: 14.2%; Average loss: 3.6686
# Iteration: 711; Percent complete: 14.2%; Average loss: 3.5199
# Iteration: 712; Percent complete: 14.2%; Average loss: 3.3818
# Iteration: 713; Percent complete: 14.3%; Average loss: 3.5335
# Iteration: 714; Percent complete: 14.3%; Average loss: 3.8555
# Iteration: 715; Percent complete: 14.3%; Average loss: 3.7089
# Iteration: 716; Percent complete: 14.3%; Average loss: 3.6535
# Iteration: 717; Percent complete: 14.3%; Average loss: 3.6955
# Iteration: 718; Percent complete: 14.4%; Average loss: 3.4210
# Iteration: 719; Percent complete: 14.4%; Average loss: 3.8817
# Iteration: 720; Percent complete: 14.4%; Average loss: 3.5118
# Iteration: 721; Percent complete: 14.4%; Average loss: 3.6929
# Iteration: 722; Percent complete: 14.4%; Average loss: 3.4717
# Iteration: 723; Percent complete: 14.5%; Average loss: 3.7363
# Iteration: 724; Percent complete: 14.5%; Average loss: 3.6066
# Iteration: 725; Percent complete: 14.5%; Average loss: 3.9561
# Iteration: 726; Percent complete: 14.5%; Average loss: 3.5564
# Iteration: 727; Percent complete: 14.5%; Average loss: 3.7910
# Iteration: 728; Percent complete: 14.6%; Average loss: 3.2913
# Iteration: 729; Percent complete: 14.6%; Average loss: 3.3909
# Iteration: 730; Percent complete: 14.6%; Average loss: 3.4706
# Iteration: 731; Percent complete: 14.6%; Average loss: 3.6826
# Iteration: 732; Percent complete: 14.6%; Average loss: 3.3914
# Iteration: 733; Percent complete: 14.7%; Average loss: 3.4043
# Iteration: 734; Percent complete: 14.7%; Average loss: 3.8389
# Iteration: 735; Percent complete: 14.7%; Average loss: 3.4780
# Iteration: 736; Percent complete: 14.7%; Average loss: 3.6785
# Iteration: 737; Percent complete: 14.7%; Average loss: 3.3856
# Iteration: 738; Percent complete: 14.8%; Average loss: 3.3474
# Iteration: 739; Percent complete: 14.8%; Average loss: 3.3820
# Iteration: 740; Percent complete: 14.8%; Average loss: 3.1823
# Iteration: 741; Percent complete: 14.8%; Average loss: 3.7564
# Iteration: 742; Percent complete: 14.8%; Average loss: 3.6680
# Iteration: 743; Percent complete: 14.9%; Average loss: 3.5583
# Iteration: 744; Percent complete: 14.9%; Average loss: 3.6508
# Iteration: 745; Percent complete: 14.9%; Average loss: 3.4719
# Iteration: 746; Percent complete: 14.9%; Average loss: 3.8272
# Iteration: 747; Percent complete: 14.9%; Average loss: 3.6050
# Iteration: 748; Percent complete: 15.0%; Average loss: 3.5550
# Iteration: 749; Percent complete: 15.0%; Average loss: 3.5863
# Iteration: 750; Percent complete: 15.0%; Average loss: 3.4818
# Iteration: 751; Percent complete: 15.0%; Average loss: 3.5934
# Iteration: 752; Percent complete: 15.0%; Average loss: 3.2925
# Iteration: 753; Percent complete: 15.1%; Average loss: 3.6948
# Iteration: 754; Percent complete: 15.1%; Average loss: 3.6994
# Iteration: 755; Percent complete: 15.1%; Average loss: 3.4254
# Iteration: 756; Percent complete: 15.1%; Average loss: 3.3756
# Iteration: 757; Percent complete: 15.1%; Average loss: 3.7309
# Iteration: 758; Percent complete: 15.2%; Average loss: 3.5985
# Iteration: 759; Percent complete: 15.2%; Average loss: 3.4606
# Iteration: 760; Percent complete: 15.2%; Average loss: 3.6061
# Iteration: 761; Percent complete: 15.2%; Average loss: 3.3947
# Iteration: 762; Percent complete: 15.2%; Average loss: 3.6033
# Iteration: 763; Percent complete: 15.3%; Average loss: 3.5113
# Iteration: 764; Percent complete: 15.3%; Average loss: 3.7237
# Iteration: 765; Percent complete: 15.3%; Average loss: 3.4039
# Iteration: 766; Percent complete: 15.3%; Average loss: 3.5852
# Iteration: 767; Percent complete: 15.3%; Average loss: 3.6594
# Iteration: 768; Percent complete: 15.4%; Average loss: 3.6415
# Iteration: 769; Percent complete: 15.4%; Average loss: 3.5754
# Iteration: 770; Percent complete: 15.4%; Average loss: 3.5813
# Iteration: 771; Percent complete: 15.4%; Average loss: 3.5364
# Iteration: 772; Percent complete: 15.4%; Average loss: 3.4771
# Iteration: 773; Percent complete: 15.5%; Average loss: 3.2882
# Iteration: 774; Percent complete: 15.5%; Average loss: 3.5052
# Iteration: 775; Percent complete: 15.5%; Average loss: 3.6297
# Iteration: 776; Percent complete: 15.5%; Average loss: 3.4895
# Iteration: 777; Percent complete: 15.5%; Average loss: 3.3486
# Iteration: 778; Percent complete: 15.6%; Average loss: 3.6267
# Iteration: 779; Percent complete: 15.6%; Average loss: 3.4215
# Iteration: 780; Percent complete: 15.6%; Average loss: 3.5594
# Iteration: 781; Percent complete: 15.6%; Average loss: 3.6162
# Iteration: 782; Percent complete: 15.6%; Average loss: 3.5049
# ...
# Iteration: 4748; Percent complete: 95.0%; Average loss: 2.4578
# Iteration: 4749; Percent complete: 95.0%; Average loss: 2.2354
# Iteration: 4750; Percent complete: 95.0%; Average loss: 2.2738
# Iteration: 4751; Percent complete: 95.0%; Average loss: 2.4529
# Iteration: 4752; Percent complete: 95.0%; Average loss: 2.2539
# Iteration: 4753; Percent complete: 95.1%; Average loss: 2.4208
# Iteration: 4754; Percent complete: 95.1%; Average loss: 2.3509
# Iteration: 4755; Percent complete: 95.1%; Average loss: 2.2618
# Iteration: 4756; Percent complete: 95.1%; Average loss: 2.3674
# Iteration: 4757; Percent complete: 95.1%; Average loss: 2.3163
# Iteration: 4758; Percent complete: 95.2%; Average loss: 2.5573
# Iteration: 4759; Percent complete: 95.2%; Average loss: 2.5279
# Iteration: 4760; Percent complete: 95.2%; Average loss: 2.4986
# Iteration: 4761; Percent complete: 95.2%; Average loss: 2.4695
# Iteration: 4762; Percent complete: 95.2%; Average loss: 2.6275
# Iteration: 4763; Percent complete: 95.3%; Average loss: 2.2889
# Iteration: 4764; Percent complete: 95.3%; Average loss: 2.3622
# Iteration: 4765; Percent complete: 95.3%; Average loss: 2.2841
# Iteration: 4766; Percent complete: 95.3%; Average loss: 2.4754
# Iteration: 4767; Percent complete: 95.3%; Average loss: 2.4582
# Iteration: 4768; Percent complete: 95.4%; Average loss: 2.5469
# Iteration: 4769; Percent complete: 95.4%; Average loss: 2.3336
# Iteration: 4770; Percent complete: 95.4%; Average loss: 2.4033
# Iteration: 4771; Percent complete: 95.4%; Average loss: 2.3296
# Iteration: 4772; Percent complete: 95.4%; Average loss: 2.5290
# Iteration: 4773; Percent complete: 95.5%; Average loss: 2.3275
# Iteration: 4774; Percent complete: 95.5%; Average loss: 2.3892
# Iteration: 4775; Percent complete: 95.5%; Average loss: 2.2324
# Iteration: 4776; Percent complete: 95.5%; Average loss: 2.3019
# Iteration: 4777; Percent complete: 95.5%; Average loss: 2.3459
# Iteration: 4778; Percent complete: 95.6%; Average loss: 2.1864
# Iteration: 4779; Percent complete: 95.6%; Average loss: 2.3727
# Iteration: 4780; Percent complete: 95.6%; Average loss: 2.4978
# Iteration: 4781; Percent complete: 95.6%; Average loss: 2.4882
# Iteration: 4782; Percent complete: 95.6%; Average loss: 2.4031
# Iteration: 4783; Percent complete: 95.7%; Average loss: 2.2035
# Iteration: 4784; Percent complete: 95.7%; Average loss: 2.5014
# Iteration: 4785; Percent complete: 95.7%; Average loss: 2.4743
# Iteration: 4786; Percent complete: 95.7%; Average loss: 2.1846
# Iteration: 4787; Percent complete: 95.7%; Average loss: 2.4435
# Iteration: 4788; Percent complete: 95.8%; Average loss: 2.3136
# Iteration: 4789; Percent complete: 95.8%; Average loss: 2.7053
# Iteration: 4790; Percent complete: 95.8%; Average loss: 2.4255
# Iteration: 4791; Percent complete: 95.8%; Average loss: 2.5981
# Iteration: 4792; Percent complete: 95.8%; Average loss: 2.5550
# Iteration: 4793; Percent complete: 95.9%; Average loss: 2.4667
# Iteration: 4794; Percent complete: 95.9%; Average loss: 2.4760
# Iteration: 4795; Percent complete: 95.9%; Average loss: 2.2549
# Iteration: 4796; Percent complete: 95.9%; Average loss: 2.5708
# Iteration: 4797; Percent complete: 95.9%; Average loss: 2.3172
# Iteration: 4798; Percent complete: 96.0%; Average loss: 2.4389
# Iteration: 4799; Percent complete: 96.0%; Average loss: 2.4072
# Iteration: 4800; Percent complete: 96.0%; Average loss: 2.3815
# Iteration: 4801; Percent complete: 96.0%; Average loss: 2.2907
# Iteration: 4802; Percent complete: 96.0%; Average loss: 2.3397
# Iteration: 4803; Percent complete: 96.1%; Average loss: 2.5336
# Iteration: 4804; Percent complete: 96.1%; Average loss: 2.6345
# Iteration: 4805; Percent complete: 96.1%; Average loss: 2.3946
# Iteration: 4806; Percent complete: 96.1%; Average loss: 2.2499
# Iteration: 4807; Percent complete: 96.1%; Average loss: 2.5499
# Iteration: 4808; Percent complete: 96.2%; Average loss: 2.3588
# Iteration: 4809; Percent complete: 96.2%; Average loss: 2.4252
# Iteration: 4810; Percent complete: 96.2%; Average loss: 2.9956
# Iteration: 4811; Percent complete: 96.2%; Average loss: 2.4126
# Iteration: 4812; Percent complete: 96.2%; Average loss: 2.5739
# Iteration: 4813; Percent complete: 96.3%; Average loss: 2.4504
# Iteration: 4814; Percent complete: 96.3%; Average loss: 2.5158
# Iteration: 4815; Percent complete: 96.3%; Average loss: 2.3157
# Iteration: 4816; Percent complete: 96.3%; Average loss: 2.4142
# Iteration: 4817; Percent complete: 96.3%; Average loss: 2.5107
# Iteration: 4818; Percent complete: 96.4%; Average loss: 2.4454
# Iteration: 4819; Percent complete: 96.4%; Average loss: 2.4374
# Iteration: 4820; Percent complete: 96.4%; Average loss: 2.3121
# Iteration: 4821; Percent complete: 96.4%; Average loss: 2.1957
# Iteration: 4822; Percent complete: 96.4%; Average loss: 2.3455
# Iteration: 4823; Percent complete: 96.5%; Average loss: 2.5549
# Iteration: 4824; Percent complete: 96.5%; Average loss: 2.2353
# Iteration: 4825; Percent complete: 96.5%; Average loss: 2.4787
# Iteration: 4826; Percent complete: 96.5%; Average loss: 2.3654
# Iteration: 4827; Percent complete: 96.5%; Average loss: 2.2268
# Iteration: 4828; Percent complete: 96.6%; Average loss: 2.4370
# Iteration: 4829; Percent complete: 96.6%; Average loss: 2.6743
# Iteration: 4830; Percent complete: 96.6%; Average loss: 2.2736
# Iteration: 4831; Percent complete: 96.6%; Average loss: 2.1562
# Iteration: 4832; Percent complete: 96.6%; Average loss: 2.2932
# Iteration: 4833; Percent complete: 96.7%; Average loss: 2.3441
# Iteration: 4834; Percent complete: 96.7%; Average loss: 2.4538
# Iteration: 4835; Percent complete: 96.7%; Average loss: 2.4498
# Iteration: 4836; Percent complete: 96.7%; Average loss: 2.3170
# Iteration: 4837; Percent complete: 96.7%; Average loss: 2.2358
# Iteration: 4838; Percent complete: 96.8%; Average loss: 2.2667
# Iteration: 4839; Percent complete: 96.8%; Average loss: 2.3607
# Iteration: 4840; Percent complete: 96.8%; Average loss: 2.4032
# Iteration: 4841; Percent complete: 96.8%; Average loss: 2.2829
# Iteration: 4842; Percent complete: 96.8%; Average loss: 2.5789
# Iteration: 4843; Percent complete: 96.9%; Average loss: 2.3584
# Iteration: 4844; Percent complete: 96.9%; Average loss: 2.4139
# Iteration: 4845; Percent complete: 96.9%; Average loss: 2.4176
# Iteration: 4846; Percent complete: 96.9%; Average loss: 2.0753
# Iteration: 4847; Percent complete: 96.9%; Average loss: 2.4553
# Iteration: 4848; Percent complete: 97.0%; Average loss: 2.5198
# Iteration: 4849; Percent complete: 97.0%; Average loss: 2.4537
# Iteration: 4850; Percent complete: 97.0%; Average loss: 2.3546
# Iteration: 4851; Percent complete: 97.0%; Average loss: 2.1772
# Iteration: 4852; Percent complete: 97.0%; Average loss: 2.1267
# Iteration: 4853; Percent complete: 97.1%; Average loss: 2.3792
# Iteration: 4854; Percent complete: 97.1%; Average loss: 2.3672
# Iteration: 4855; Percent complete: 97.1%; Average loss: 2.4124
# Iteration: 4856; Percent complete: 97.1%; Average loss: 2.2744
# Iteration: 4857; Percent complete: 97.1%; Average loss: 2.4767
# Iteration: 4858; Percent complete: 97.2%; Average loss: 2.3515
# Iteration: 4859; Percent complete: 97.2%; Average loss: 2.5061
# Iteration: 4860; Percent complete: 97.2%; Average loss: 2.5555
# Iteration: 4861; Percent complete: 97.2%; Average loss: 2.4292
# Iteration: 4862; Percent complete: 97.2%; Average loss: 2.6187
# Iteration: 4863; Percent complete: 97.3%; Average loss: 2.1462
# Iteration: 4864; Percent complete: 97.3%; Average loss: 2.3060
# Iteration: 4865; Percent complete: 97.3%; Average loss: 2.3337
# Iteration: 4866; Percent complete: 97.3%; Average loss: 2.4935
# Iteration: 4867; Percent complete: 97.3%; Average loss: 2.4126
# Iteration: 4868; Percent complete: 97.4%; Average loss: 2.3997
# Iteration: 4869; Percent complete: 97.4%; Average loss: 2.3772
# Iteration: 4870; Percent complete: 97.4%; Average loss: 2.1903
# Iteration: 4871; Percent complete: 97.4%; Average loss: 2.3916
# Iteration: 4872; Percent complete: 97.4%; Average loss: 2.2692
# Iteration: 4873; Percent complete: 97.5%; Average loss: 2.4477
# Iteration: 4874; Percent complete: 97.5%; Average loss: 2.5690
# Iteration: 4875; Percent complete: 97.5%; Average loss: 2.3341
# Iteration: 4876; Percent complete: 97.5%; Average loss: 2.1865
# Iteration: 4877; Percent complete: 97.5%; Average loss: 2.6439
# Iteration: 4878; Percent complete: 97.6%; Average loss: 2.4726
# Iteration: 4879; Percent complete: 97.6%; Average loss: 2.5812
# Iteration: 4880; Percent complete: 97.6%; Average loss: 2.2160
# Iteration: 4881; Percent complete: 97.6%; Average loss: 2.3851
# Iteration: 4882; Percent complete: 97.6%; Average loss: 2.4494
# Iteration: 4883; Percent complete: 97.7%; Average loss: 2.3731
# Iteration: 4884; Percent complete: 97.7%; Average loss: 2.2154
# Iteration: 4885; Percent complete: 97.7%; Average loss: 2.3847
# Iteration: 4886; Percent complete: 97.7%; Average loss: 2.3610
# Iteration: 4887; Percent complete: 97.7%; Average loss: 2.1902
# Iteration: 4888; Percent complete: 97.8%; Average loss: 2.2905
# Iteration: 4889; Percent complete: 97.8%; Average loss: 2.4091
# Iteration: 4890; Percent complete: 97.8%; Average loss: 2.3995
# Iteration: 4891; Percent complete: 97.8%; Average loss: 2.4909
# Iteration: 4892; Percent complete: 97.8%; Average loss: 2.1607
# Iteration: 4893; Percent complete: 97.9%; Average loss: 2.3937
# Iteration: 4894; Percent complete: 97.9%; Average loss: 2.2013
# Iteration: 4895; Percent complete: 97.9%; Average loss: 2.2898
# Iteration: 4896; Percent complete: 97.9%; Average loss: 2.1481
# Iteration: 4897; Percent complete: 97.9%; Average loss: 2.3462
# Iteration: 4898; Percent complete: 98.0%; Average loss: 2.4809
# Iteration: 4899; Percent complete: 98.0%; Average loss: 2.3996
# Iteration: 4900; Percent complete: 98.0%; Average loss: 2.5682
# Iteration: 4901; Percent complete: 98.0%; Average loss: 2.2600
# Iteration: 4902; Percent complete: 98.0%; Average loss: 2.5748
# Iteration: 4903; Percent complete: 98.1%; Average loss: 2.1011
# Iteration: 4904; Percent complete: 98.1%; Average loss: 2.6184
# Iteration: 4905; Percent complete: 98.1%; Average loss: 2.5941
# Iteration: 4906; Percent complete: 98.1%; Average loss: 2.2737
# Iteration: 4907; Percent complete: 98.1%; Average loss: 2.3206
# Iteration: 4908; Percent complete: 98.2%; Average loss: 2.4316
# Iteration: 4909; Percent complete: 98.2%; Average loss: 2.2185
# Iteration: 4910; Percent complete: 98.2%; Average loss: 2.2448
# Iteration: 4911; Percent complete: 98.2%; Average loss: 2.4733
# Iteration: 4912; Percent complete: 98.2%; Average loss: 2.1684
# Iteration: 4913; Percent complete: 98.3%; Average loss: 2.4660
# Iteration: 4914; Percent complete: 98.3%; Average loss: 2.3327
# Iteration: 4915; Percent complete: 98.3%; Average loss: 2.4771
# Iteration: 4916; Percent complete: 98.3%; Average loss: 2.3920
# Iteration: 4917; Percent complete: 98.3%; Average loss: 2.3143
# Iteration: 4918; Percent complete: 98.4%; Average loss: 2.3644
# Iteration: 4919; Percent complete: 98.4%; Average loss: 2.3554
# Iteration: 4920; Percent complete: 98.4%; Average loss: 2.3655
# Iteration: 4921; Percent complete: 98.4%; Average loss: 2.1955
# Iteration: 4922; Percent complete: 98.4%; Average loss: 2.2455
# Iteration: 4923; Percent complete: 98.5%; Average loss: 2.5422
# Iteration: 4924; Percent complete: 98.5%; Average loss: 2.3357
# Iteration: 4925; Percent complete: 98.5%; Average loss: 2.2368
# Iteration: 4926; Percent complete: 98.5%; Average loss: 2.4026
# Iteration: 4927; Percent complete: 98.5%; Average loss: 2.3273
# Iteration: 4928; Percent complete: 98.6%; Average loss: 2.1347
# Iteration: 4929; Percent complete: 98.6%; Average loss: 2.5470
# Iteration: 4930; Percent complete: 98.6%; Average loss: 2.3700
# Iteration: 4931; Percent complete: 98.6%; Average loss: 2.3367
# Iteration: 4932; Percent complete: 98.6%; Average loss: 2.4585
# Iteration: 4933; Percent complete: 98.7%; Average loss: 2.1943
# Iteration: 4934; Percent complete: 98.7%; Average loss: 2.2694
# Iteration: 4935; Percent complete: 98.7%; Average loss: 2.3870
# Iteration: 4936; Percent complete: 98.7%; Average loss: 2.6319
# Iteration: 4937; Percent complete: 98.7%; Average loss: 2.1340
# Iteration: 4938; Percent complete: 98.8%; Average loss: 2.3059
# Iteration: 4939; Percent complete: 98.8%; Average loss: 2.2830
# Iteration: 4940; Percent complete: 98.8%; Average loss: 2.2071
# Iteration: 4941; Percent complete: 98.8%; Average loss: 2.4610
# Iteration: 4942; Percent complete: 98.8%; Average loss: 2.5453
# Iteration: 4943; Percent complete: 98.9%; Average loss: 2.4187
# Iteration: 4944; Percent complete: 98.9%; Average loss: 2.4860
# Iteration: 4945; Percent complete: 98.9%; Average loss: 2.1337
# Iteration: 4946; Percent complete: 98.9%; Average loss: 2.4928
# Iteration: 4947; Percent complete: 98.9%; Average loss: 2.4529
# Iteration: 4948; Percent complete: 99.0%; Average loss: 2.3404
# Iteration: 4949; Percent complete: 99.0%; Average loss: 2.4422
# Iteration: 4950; Percent complete: 99.0%; Average loss: 2.3160
# Iteration: 4951; Percent complete: 99.0%; Average loss: 2.4170
# Iteration: 4952; Percent complete: 99.0%; Average loss: 2.1438
# Iteration: 4953; Percent complete: 99.1%; Average loss: 2.2386
# Iteration: 4954; Percent complete: 99.1%; Average loss: 2.4815
# Iteration: 4955; Percent complete: 99.1%; Average loss: 2.1078
# Iteration: 4956; Percent complete: 99.1%; Average loss: 2.3984
# Iteration: 4957; Percent complete: 99.1%; Average loss: 2.2129
# Iteration: 4958; Percent complete: 99.2%; Average loss: 2.4163
# Iteration: 4959; Percent complete: 99.2%; Average loss: 2.2143
# Iteration: 4960; Percent complete: 99.2%; Average loss: 2.5990
# Iteration: 4961; Percent complete: 99.2%; Average loss: 2.3971
# Iteration: 4962; Percent complete: 99.2%; Average loss: 2.4420
# Iteration: 4963; Percent complete: 99.3%; Average loss: 2.2271
# Iteration: 4964; Percent complete: 99.3%; Average loss: 2.2864
# Iteration: 4965; Percent complete: 99.3%; Average loss: 2.2282
# Iteration: 4966; Percent complete: 99.3%; Average loss: 2.3780
# Iteration: 4967; Percent complete: 99.3%; Average loss: 2.6661
# Iteration: 4968; Percent complete: 99.4%; Average loss: 2.2760
# Iteration: 4969; Percent complete: 99.4%; Average loss: 2.4203
# Iteration: 4970; Percent complete: 99.4%; Average loss: 2.3761
# Iteration: 4971; Percent complete: 99.4%; Average loss: 2.2832
# Iteration: 4972; Percent complete: 99.4%; Average loss: 2.3225
# Iteration: 4973; Percent complete: 99.5%; Average loss: 2.4014
# Iteration: 4974; Percent complete: 99.5%; Average loss: 2.2888
# Iteration: 4975; Percent complete: 99.5%; Average loss: 2.3531
# Iteration: 4976; Percent complete: 99.5%; Average loss: 2.1943
# Iteration: 4977; Percent complete: 99.5%; Average loss: 2.3325
# Iteration: 4978; Percent complete: 99.6%; Average loss: 2.4235
# Iteration: 4979; Percent complete: 99.6%; Average loss: 2.3373
# Iteration: 4980; Percent complete: 99.6%; Average loss: 2.2748
# Iteration: 4981; Percent complete: 99.6%; Average loss: 2.3809
# Iteration: 4982; Percent complete: 99.6%; Average loss: 2.3324
# Iteration: 4983; Percent complete: 99.7%; Average loss: 2.4904
# Iteration: 4984; Percent complete: 99.7%; Average loss: 2.4671
# Iteration: 4985; Percent complete: 99.7%; Average loss: 2.4958
# Iteration: 4986; Percent complete: 99.7%; Average loss: 2.5273
# Iteration: 4987; Percent complete: 99.7%; Average loss: 2.2970
# Iteration: 4988; Percent complete: 99.8%; Average loss: 2.1308
# Iteration: 4989; Percent complete: 99.8%; Average loss: 2.4428
# Iteration: 4990; Percent complete: 99.8%; Average loss: 2.3728
# Iteration: 4991; Percent complete: 99.8%; Average loss: 2.3116
# Iteration: 4992; Percent complete: 99.8%; Average loss: 2.3411
# Iteration: 4993; Percent complete: 99.9%; Average loss: 2.3589
# Iteration: 4994; Percent complete: 99.9%; Average loss: 2.2500
# Iteration: 4995; Percent complete: 99.9%; Average loss: 2.3268
# Iteration: 4996; Percent complete: 99.9%; Average loss: 2.3369
# Iteration: 4997; Percent complete: 99.9%; Average loss: 2.3108
# Iteration: 4998; Percent complete: 100.0%; Average loss: 2.1827
# Iteration: 4999; Percent complete: 100.0%; Average loss: 2.3932
# Iteration: 5000; Percent complete: 100.0%; Average loss: 2.4702

# %% [markdown]
# Run Evaluation
# ==============
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# >  hi
# Bot: hi . . . . .
# >  mardia
# Error: Encountered unknown word.
# >  mimmah
# Error: Encountered unknown word.
# >  hiow are you??
# Error: Encountered unknown word.
# >  how are you??
# Bot: i m fine . . . .
# >  why you are fine??
# Bot: i m fine . . . .
# >  fuck you??
# Bot: yeah . . . . .
# >  fuck you
# Bot: i m sorry i m sorry . .
# >  tell me about us??
# Bot: i don t know . . .

# %% [markdown]
# Conclusion
# ==========
#
# That's all for this one, folks. Congratulations, you now know the
# fundamentals to building a generative chatbot model! If you're
# interested, you can try tailoring the chatbot's behavior by tweaking the
# model and training parameters and customizing the data that you train
# the model on.
#
# Check out the other tutorials for more cool deep learning applications
# in PyTorch!
